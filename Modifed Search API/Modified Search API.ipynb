# %%
import sys
import got3 as got
import csv

def main():

    def printTweet(descr, t):
        print(descr)
        print("Username: %s" % t.username)
        print("Retweets: %d" % t.retweets)
        print("Text: %s" % t.text)
        print("Mentions: %s" % t.mentions)
        print("Hashtags: %s\n" % t.hashtags)


    #Get historical tweets by query search
    tweetCriteria = got.manager.TweetCriteria().setQuerySearch('Joe Biden').setSince("2020-02-19").setUntil("2020-02-20").setMaxTweets(5000)
    tweets = got.manager.TweetManager.getTweets(tweetCriteria)
    
    for tweet in tweets:
        printTweet("Get tweets by query search [Joe Biden]", tweet)
        
    #get the name of the spreadsheet we will write to
    fname = "biden_day_of_dem_debate"
    #open the spreadsheet we will write to
    with open('%s.csv' % (fname), 'w') as file:
        w = csv.writer(file)

        #write header row to spreadsheet
        w.writerow(['timestamp', 'Username', 'Retweets', 'Text', 'Mentions', 'Hashtags'])

        #for each tweet matching our hashtags, write relevant info to the spreadsheet
        for tweet in tweets:
            w.writerow([tweet.formatted_date, tweet.author_id, tweet.retweets, 
                        tweet.text, tweet.mentions,
                        tweet.hashtags])

if __name__ == '__main__':
    main()
# Out:
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: I like salty Biden when you can tell it’s genuine annoyance.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: #ACD is new in your feed! @MikeBloomberg qualifies for his first debate as he surges in the polls while @JoeBiden banks on a big win this weekend in Nevada. Plus, @ZachEClark & @PreemoTees unveil new power rankings and drop a new #ShutUpAlready! LISTEN:https://anchor.fm/a-common-divide/episodes/A-Common-Divide----February-19--2020-eaumud …
# Mentions: @MikeBloomberg @JoeBiden @ZachEClark @PreemoTees
# Hashtags: #ACD #ShutUpAlready
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: I think you meant to tag @JoeBiden not @JoeBudden lol
# Mentions: @JoeBiden @JoeBudden
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: This would be more powerful if it were true.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Go team Joe Biden!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: He won’t run against Biden because of the told makeup’s story of how shameful his son was doing business in a foreign government gas company! With 60% of his backers leaving him. GOPIGS are traitors to America people and they will do anything to protect 45 so they can destroy USA
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: damn you got me, no one ever gets their account banned or says the word elect in an election bernie is the only one with a block who won't vote blue no matter who. if you try to get someone else to win the primary, it proves you want a weaker candidate vs trump.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: I saw "Coffin Joe" trending and it made me scared for Joe Biden... Turns out it had nothing to do with him
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: You're open to a Republican VP, though.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: pic.twitter.com/SjEO3rglgz
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: @JoeBiden https://twitter.com/ljreina/status/1108146864380170240 …
# Mentions: @JoeBiden
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 2
# Text: Now that’s a powerful endorsement.pic.twitter.com/l4G41xAooX
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: @SenSanders @JoeBiden @AOC,stopping attacking others of @TheDemocrats!!!! This only plays into the hands of POTUS:I.E.'divide the competition,&have them destroy their flanks,&finally"conquer"by destroying what is left over". Stop attacking each other!!!! Policy difference onlyhttps://twitter.com/CNN/status/1229999560006696960 …
# Mentions: @SenSanders @JoeBiden @AOC @TheDemocrats
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Trump has done a fantastic job! Just think how much more he could accomplish with a house willing to work with him instead of doing everything to fight him and the good of the country. TRUMP FIGHTS FOR THE PEEPS DAILY & THE DEMS FIGHT HIM! That’s a fact! #TRUMP2020 #VoteRep2020
# Mentions:
# Hashtags: #TRUMP2020 #VoteRep2020
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: pic.twitter.com/WY3I4W8afD
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Don’t play the age card.....it will boomerang
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: And reverse his E.O.’s.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Several Joe Biden fundraisers jump ship from his struggling campaign to back Mike Bloomberg https://cnb.cx/39L1YfZ It's a rat!!! Jump! Lol
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: The NRA did not fund Bernie, members of the NRA which are in the thousands did donate. I'm a NRA member and I donate to him. So what's your point?
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: @MikeBloomberg @ewarren @JoeBiden @amyklobuchar @PeteButtigieg @BernieSanders Y’all, minimize the in-fighting tonight cause Voters are sick of divisiveness. Show us “YOUR” Leadership Qualities. One last thing: there’s nothing undemocratic about a citizen using HIS OWNTO RUN!
# Mentions: @MikeBloomberg @ewarren @JoeBiden @amyklobuchar @PeteButtigieg @BernieSanders
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Joe Biden for Senator.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Ah, don't worry. They won't disappoint. They'll spend their time at the debate tonight taking shots at each other rather than using the time going after Comrade Trumpski's show. @JoeBiden @Mike2020 @PeteButtigieg @amyklobuchar @BernieSanders @ewarren
# Mentions: @JoeBiden @Mike2020 @PeteButtigieg @amyklobuchar @BernieSanders @ewarren
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: You will when I beat you ;)
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: pic.twitter.com/qpiFYPH1V6
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Epstein didn’t kill himself
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: That is ugly honor you word
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: #BernieSanders #SouthCarolinaPrimary #BernieSanders2020 #JoeBiden #Biden2020 #Sanders2020 #ElizabethWarren #Warren2020 #PeteForAmerica #PeteButtigieg #PeteForPresident #PeteButtigieg2020 #MichaelBloomberg #JoeBiden2020 #ElizabethWarren2020 #Nevadahttps://youtu.be/dULraIiRd5k
# Mentions:
# Hashtags: #BernieSanders #SouthCarolinaPrimary #BernieSanders2020 #JoeBiden #Biden2020 #Sanders2020 #ElizabethWarren #Warren2020 #PeteForAmerica #PeteButtigieg #PeteForPresident #PeteButtigieg2020 #MichaelBloomberg #JoeBiden2020 #ElizabethWarren2020 #Nevadahttps
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Good luck to our unifying moderates @amyklobuchar, @JoeBiden and @PeteButtigieg. Whom represent the millions of us who are tried of wishful platforms and empty promises. Tonight, is the night to come out on top. Let’s win. #DemDebate #NevadaCaucus2020
# Mentions: @amyklobuchar @JoeBiden @PeteButtigieg
# Hashtags: #DemDebate #NevadaCaucus2020
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Nah. Talking about the cheeto.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: You’re “shocked?” Really? Why isn’t the MSM vetting @BernieSanders? @JoeBiden has been vetted up, down, sideways and backwards. So has @MikeBloomberg. Why not Bernie?
# Mentions: @BernieSanders @JoeBiden @MikeBloomberg
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: I'm voting for @Biden2020
# Mentions: @Biden2020
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 43
# Text: You @JoeBiden took on the @nra ? You can’t even manage an IRAhttps://twitter.com/JoeBiden/status/1230251966003130369 …
# Mentions: @JoeBiden @nra
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: You good with a socialist who will implement government control over every aspect of your life as he raises your taxes to an unsustainable amount ?? Not to mention gas, food, interest rates etc ..... You’re willing to throw America over a cliff ?
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: It’s usually made by the same crowd that says Joe Biden is basically a Republican.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: I noticed that Bloomberg is using advertising with Barack Obama in it. So is Barack Obama backing Bloomberg and if so why did he turn his back on Joe Biden. I would think since he was his vice president he would be standing behind Joe Biden. Is this a Bloomberg trick?
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Uh...pic.twitter.com/1BuyeQisIw
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Vice President @JoeBiden2020 for the SOUL of the NATION https://twitter.com/JoeBiden/status/1230277131726413824 …
# Mentions: @JoeBiden2020
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Trump and Bloomberg are the same thing goshhh
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: https://twitter.com/_MUDUTU_/status/1230214150774718464?s=19 …
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: It’s a head fake. Trump wants to run agains Bernie.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: https://t.co/rbDun8dsFB https://twitter.com/mike2020/status/1230185349571383296?s=21 …
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: So you think he's not an idiot?
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text:
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Don’t forget Maxine Waters Joe Biden https://twitter.com/Education4Libs/status/1229986435094253568 …
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 2
# Text: FBI raid connected to Joe Biden’s brother https://thehornnews.com/fbi-raid-connected-to-joe-bidens-brother/ … via @ReadTheHornNews I guess it just runs in the Biden family OMG.
# Mentions: @ReadTheHornNews
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Inasmuch as I want a woman to be elected POTUS it doesn’t seem to be in 2020. I keep hoping it will be @KamalaHarris since she has all the tools to be a great president. Maybe if she was @JoeBiden VP it will sooner. #MadamPresident #BidenHarris2020
# Mentions: @KamalaHarris @JoeBiden
# Hashtags: #MadamPresident #BidenHarris2020
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: The label of “Democrat” really doesn’t carry weight. Policy is what matters. Also, given the state of the party right now, I wouldn’t say he has bragging rights. His response to that tweet, however, was good. Not remotely true, but good nonetheless.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: They can join up with Joe Biden because Biden used to go by Cool Dean, back then he was telling people his name was Dean and he started a leather jacket company with Barack Obama. It was called Dean's leather jackets.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Joe’s policies gave us Trump. Hard pass
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Ann!! Hi!!Fellow #LeslieJones fan!
# Mentions:
# Hashtags: #LeslieJones
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text:
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 2
# Text: You won't see this on CNN:https://www.bbc.com/news/world-europe-34710373 …
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Now you're really embarrassing yourself. Joe Biden does NOT endorse REPUBLICANS. SIT. TF. DOWN. BLOOMBERG. #Biden2020 #BidenBeatsTrump #BloombergIsRacist #BloombergTwoStents #BloombergIsARacist #NeverBloombergpic.twitter.com/epFoTeKrGN
# Mentions:
# Hashtags: #Biden2020 #BidenBeatsTrump #BloombergIsRacist #BloombergTwoStents #BloombergIsARacist #NeverBloombergpic
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: That’s an understatement!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Watch one Nina Turner speech, and you’ll understand why Bernie Sanders is the man to do it.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 1
# Text: Especially at this precarious moment!!!! You’ve got my vote, Joe!!!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: The last thing we need is another businessman in the WH. We need a natural born leader who bring Dems/Republicans/Indies n many more, together. Joe is a centerist Dem who is charismatic, experienced, liked/respected world over and he's been in WH/government for 8 years. VOTE JOE
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Ok for real. I’ve watched predebate coverage all day. The MSM is covering Bernie & Mike wall to wall. As if just those 2 are left. Scattered mentions of @JoeBiden @PeteButtigieg @ewarren @amyklobuchar. Totally bias and manipulative. #mediablackout #DemDebate
# Mentions: @JoeBiden @PeteButtigieg @ewarren @amyklobuchar
# Hashtags: #mediablackout #DemDebate
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Dems are not socialist, Bernie will be a disaster if he wins, Trump would get reelected, Bloomburg will buy his way in, he has the $$ and Tom Perez, and the DNC will let it happen.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Obama: 'I Have No Memory Of Anyone Named Joe Biden' https://babylonbee.com/news/barack-obama-i-have-no-memory-of-anyone-named-joe-biden … via @TheBabylonBee
# Mentions: @TheBabylonBee
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: I understand what Biden is attempting to do.. He’s basically calling Bloomberg a racist without actually saying it.. https://twitter.com/mike2020/status/1230185349571383296?s=21 …https://twitter.com/Mike2020/status/1230185349571383296 …
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 1
# Text: She is third in delegates! #InvincibleNotInvisibleWarren
# Mentions:
# Hashtags: #InvincibleNotInvisibleWarren
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: FBI Raids Company Tied to Joe Biden's Brother - https://neonnettle.com/news/10361-fbi-raids-company-tied-to-joe-biden-s-brother?utm_source=Neon … Nettle News
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Who is Joe Biden
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: So, you’re endorsing President Trump? “The White House is no place for on-the-job training. We need a president who will be ready on day one.” He’s the only one who has actually been president.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: You couldn’t endorse a ham sammich they wouldn’t even take it seriously. Joe, move to Florida, by you some Flip flops and play some golf. Retire already.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: They aren't getting a pass. But your boy, Joe, doesn't seem to have it at this point.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Did you plagiarize that?
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Sir you've already lost the nomination.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: joe has that look like he just pooped his pampers
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: I am so ready for Joe Biden to turn into fucking Sephiroth live on stage and decapitate Bloomberg with a giant katana
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: We’d take Sully.pic.twitter.com/1CDHgtS00W
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: My dad once told me why he wanted all his li'l girls learn how to swim b/c once you all learned how not to panic in water, you would not panic in life. What does CPT Sully know? Stay Calm cool and sturdy. Unlike what we have in WH who had to cheat 2 get in & cheating 2 stay in
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: pic.twitter.com/ub57gop8kV
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: please provide proof that your property taxes have doubled?if your home value doubled that's one thing. but to make a outlandish statement of doubled is ridiculous.also, we have a very minor increase in homeless, but most mayors are making it worse. not federal policies.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Keep thinking that!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: This is doctored! @jack
# Mentions: @jack
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: If you don't know, just say so. It's okay. Spend the entire debate lifting each other up. Not one negative thing. Do NOT let them pit you against each other. That helps tRump, not you. Go out of your way to praise each other. Show *US* what unity looks like.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 2
# Text: @JoeBiden @amyklobuchar @ewarren @HallieJackson @chucktodd @BernieSanders @MikeBloomberghttps://twitter.com/WendyMeer11/status/1230279920795955200 …
# Mentions: @JoeBiden @amyklobuchar @ewarren @HallieJackson @chucktodd @BernieSanders @MikeBloomberghttps
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Obama pretty much got on the job training
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: PMSNBC, hahahaha!!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Shhhhh go to sleep
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 1
# Text: Summary letters are the standard re medical record release for other candidates https://www.politico.com/amp/news/2019/12/30/sanders-releases-letters-doctors-health-091263 …. @JoeBiden s letter summary: https://www.usnews.com/news/elections/articles/2019-12-17/biden-releases-medical-records?context=amp …pic.twitter.com/LgyhaT1n3h
# Mentions: @JoeBiden
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: pic.twitter.com/GlWVoEqK7t
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: https://twitter.com/i/status/1230262104516632577 … #usarmedforces #usmc #Deplorables #LawEnforcement #usaf #ice #USArmy #USNavy #KAGA #WalkAwayFromDemocratSocialists #berniesanders #joebiden #MiniMike #brexit #aoc #omar #TheSquad #mediablackout #DemocratsHateAmerica #TrumpTrain #teaparty #EnemyOfThePeople
# Mentions:
# Hashtags: #usarmedforces #usmc #Deplorables #LawEnforcement #usaf #ice #USArmy #USNavy #KAGA #WalkAwayFromDemocratSocialists #berniesanders #joebiden #MiniMike #brexit #aoc #omar #TheSquad #mediablackout #DemocratsHateAmerica #TrumpTrain #teaparty #EnemyOfThePeople
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 1
# Text: No. He is attacking him *now* in NV with $250K attack ads, & he’s not leading the field. He’s doing it bc he’s scared of Biden. This has nothing to do with Obama. He’s doing it bc he knows he’ll lose to him. He’s not attacking sanders (he’s helping him) bc he knows he’ll beat him
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Biden background check....pic.twitter.com/xz8tX0cSuV
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: JoeBiden: "In important things like flying or the running of a nation, experience makes the difference between success and failure." — Captain "Sully" Sullenberger The White House is no place for on-the-job training. We need a president who will be read… pic.twitter.com/XcLug0QWcP
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Well, at least Sully knows how to survive a crash.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: pic.twitter.com/hacw54d1Kp
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: I totally support Susan Collins after the Democrats found no evidence of Russian collusion, wasted time and tax payer dollars to exaggerate the Ukraine call, all the time covering up for Hunter and Joe Biden! Thank you Susan for understanding the Truth!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Flush that mess down the toilet... trump
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: I hope @JoeBiden releases years of detailed medical history tonight before the debate and then brings it up, just to push Bernard into a corner. Do it Joe!
# Mentions: @JoeBiden
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Childrens Healthcare:https://www.commondreams.org/news/2017/12/20/without-fixes-daca-and-chip-sanders-vows-vote-no-spending-bill …
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Exactly that’s why we have PRESIDENT TRUMP.!!!!!! #CorruptDemocrats #BidenCrimeFamilypic.twitter.com/2rQu7KM6cq
# Mentions:
# Hashtags: #CorruptDemocrats #BidenCrimeFamilypic
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: joe biden is racist
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: I totally support Susan Collins after the Democrats found no evidence of Russian collusion, wasted time and tax payer dollars to exaggerate the Ukraine call, all the time covering up for Hunter and Joe Biden! Thank you Susan for understanding the Truth!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Trump is the man
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Says the person who dismisses candidates because of their age and gender, nice.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: You did in 2018. And you got paid for it.https://www.nytimes.com/2019/01/23/us/politics/biden-speech-fred-upton.html …
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Yes joe!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: If you listen to CNN MSNBC you would think Joe Biden already quit they haven't mentioned his name in 2 days
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Even better would be for the actual Democrats to work together: @PeteButtigieg & @amyklobuchar go hard against Bloomberg, @JoeBiden & @ewarren go hard at Bernie As a Democrat, I'd love to see a Democratic Party primary between Democratshttps://twitter.com/davidaxelrod/status/1230141495522529280?s=20 …
# Mentions: @PeteButtigieg @amyklobuchar @JoeBiden @ewarren
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: It shouldn't take long to discuss ruining healthcare, ruining the economy, and selling us out to Iran and China. Go for it!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: pic.twitter.com/LHbdGArK61
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: The Constitution disagrees. ANY American aged 35 or over, a natural born citizen, and a resident of the US for at least 14 years can become president. There is no requirement that corrupt politicians are the only ones qualified, so even Biden would need training as President.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Biden Supporter, I understand your enthusiasm for Joe, and continue to support him through the end of his campaign. But once he suspends, I hope you will join the one candidate with the resources to defeat Trump. Join us .http://MikeBloomberg.com
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: @Mike2020 needs to call for the release of #Sanders FBI file. Trump has it and will use. Dems need to know what is tgere before it too late. @JoeBiden
# Mentions: @Mike2020 @JoeBiden
# Hashtags: #Sanders
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: T-minus 2 hours until the #DemDebate. Will Joe Biden... - Finally consolidate support among moderates - Call Chuck Todd a lying dog-faced pony soldier - Feast on the brains of his fellow presidential hopefuls https://youtu.be/MqJ6kzxtj_I
# Mentions:
# Hashtags: #DemDebate
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: You ARE a Republican.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 6
# Text: Esta noche es noche de debate electoral demócrata, y estos son los participantes: • @PeteButtigieg • @JoeBiden • @BernieSanders • @ewarren • @MikeBloomberg (debuta) • @amyklobuchar #DemDebate #elecciones2020pic.twitter.com/p2aNxVNjd1
# Mentions: @PeteButtigieg @JoeBiden @BernieSanders @ewarren @MikeBloomberg @amyklobuchar
# Hashtags: #DemDebate #elecciones2020pic
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Here are the clues you aren't even an American: 1) You just joined Twitter 2) You said the Democrats should "elect" Bernie as the nominee. Nobody talks like that. You don't "elect" a nominee. So . . . good try. You had me for a while comrade.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: I am trying to figure out who will exploit social media to beat Trump and then regulate Facebook into oblivion. Who has the guts to break the machine that gave them the presidency? Who will walk through the Stargate and never go back? That is my single issue. Still no answer.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 1
# Text: I'm an (actual, ideological) libertarian. The LP has its head up its ass.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: I respect him as a pilot, but ol joe has been in training for way too many years sucking from the taxpayer tit. His training is over and has been for a very long time.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: You seem very prepared!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Oh boy that'll be exciting
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: pic.twitter.com/HSnONt0WTk
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: National hero.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: If you were a pilot would have crashed your plane multiple times. The whole pilot verses political experience is ludicrous.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Bernie's not poor. He's actually quite wealthy.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Why was the prosecutor you extorted poisoned after releasing an affidavit detailing the corruption of your family in the Ukraine?
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: you are not a leader
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Brave "Sully"...I just watched the movie a week ago....
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: No you don't. You just would consider 1 as you VP.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: I personally think it is because he thinks that Biden is circling the drain and he wants to finish him off now.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 1
# Text: There is only one person on the stage tonight that has the brains (albeit slightly damaged from an aneurysm) to lead this country and that is Joseph Robinette Biden Jr @JoeBiden #DemDebate
# Mentions: @JoeBiden
# Hashtags: #DemDebate
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Shit gets real. I would vote for @JoeBiden — I will not vote for @MikeBloomberg. (I’m #TeamWarren — the best option — and policy-wise, to the left of @BernieSanders; I cannot in good faith vote for #bloomberg and would not.)https://twitter.com/VABVOX/status/1230278483521286149 …
# Mentions: @JoeBiden @MikeBloomberg @BernieSanders
# Hashtags: #TeamWarren #bloomberg
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: It would be really beautiful if everyone; @BernieSanders, @amyklobuchar, @JoeBiden, @ewarren, and @PeteButtigieg could come together tonight and tell @MikeBloomberg to stick his own dick in his ass and fuck himself. #DemDebate #DropOutBloomberg
# Mentions: @BernieSanders @amyklobuchar @JoeBiden @ewarren @PeteButtigieg @MikeBloomberg
# Hashtags: #DemDebate #DropOutBloomberg
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 2
# Text: I would say 2/3rd of the remaining candidates have crapped all over Obama. The only person he "should" campaign for is Joe Biden and that's only because he was Obama's VP: https://twitter.com/Alllwftopic/status/1230267466762223616 …
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: #JoeBiden will beat trump. https://twitter.com/SallyDeal4/status/1230193431130959872 …
# Mentions:
# Hashtags: #JoeBiden
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: He lands a plane in the water and saves lives doesn't make you a good candidates for president. You've been pandering to minorities for forty six years. Speaking ebonics to them doesn't help. You and bernie Barkley accomplished anything in 90 years combined
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: So how deep into boomer tweets are you going to go until you start posting facebook grandma memes?
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: sink like a stone! one plutocratic coin. If @MikeBloomberg's Campaign repulses me, & @realDonaldTrump's Campaign entertains me then @jacobgreber, @shaunking, @zdaniel, @WatchCenter& @AdamParkhomenko, @JoeBiden's #Election2020 campaign is just plain sad! I don't mind #Auspol
# Mentions: @MikeBloomberg @realDonaldTrump @jacobgreber @shaunking @zdaniel @WatchCenter @AdamParkhomenko @JoeBiden
# Hashtags: #Election2020 #Auspol
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Tom Brady is the Joe Biden of quarterbacks.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Will of the people?pic.twitter.com/ns0OLS06bI
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 4
# Text: No one has done such a great job at making me Like Joe Biden like Bloomberg
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: We need huge demonstrations for “ Memorial Day, The 4th of July and Labor Day! Don’t let these guys eliminate Joe Biden from the race! That’s what they are doing to him right now! Joe Biden will not sell us out for a buck, so he has to go! Keep your eyes on Chuck Todd!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: I like a good comeback good on you!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: You're nuts....
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Let’s not rule out #Biden he can unite this Country and knows how to work with Republicans
# Mentions:
# Hashtags: #Biden
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: This is an absurd argument. If the Russian govt. started promoting Joe Biden's candidacy because it served their goals (WITHOUT his consent or involvement, which is the key point here... that's what happened with Bernie) would you call on him to drop out?
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: pic.twitter.com/KF1lT63TJb
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: The fact of the matter is, he’s done
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Joe Biden had a detailed health report!! If you have nothing to hide and are proud of your health you brag about it in PRINT!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Name a crisis
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: You’re delusional ...... again !
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Hey Joe How much were you paid..... @JoeBiden ????? https://twitter.com/Bananas4Bernie/status/1230252302994247681 …
# Mentions: @JoeBiden
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: pic.twitter.com/yEGyAOvs38
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Hey #Democrats during the debate tonight, if everyone on the #DemocraticDebate stage doesn’t rip #Bloomberg a new one, then they don’t deserve to be in this race! #MakeBloombergCry #NeverBloomberg #BernieSanders2020 #ElizabethWarren2020 #AmyKlobuchar #PeteButtigieg #JoeBiden
# Mentions:
# Hashtags: #Democrats #DemocraticDebate #Bloomberg #MakeBloombergCry #NeverBloomberg #BernieSanders2020 #ElizabethWarren2020 #AmyKlobuchar #PeteButtigieg #JoeBiden
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Packed house? My daughter has more people at her birthday parties.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Dems took money over ethics letting him in th debate. We see through it and it probes dishonesty in the worst way. They're just proving they can and will be bought to get what they want. Not my partyofchoice anymore
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 20
# Text: If Joe Biden: - Had a heart attack - Refused to release his medical records - Supported Stop and Frisk - Called Trans People “men in dresses” - Bought his way into the election He would be viscously torn apart by the media. But Mike and Bernie get a pass. Why is that? pic.twitter.com/8sXaueh0il
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 4
# Text: Joe Biden, Mayor Pete, and Mike Bloomberg are all proposing to "build on the Affordable Care Act" as their health care plans. This means bringing back hated and coercive individual mandate taxes. Let's see if they're asked about this tonight. #DemDebate
# Mentions:
# Hashtags: #DemDebate
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: No, no we don’t. I’m voting Libertarian, any one of their candidates is better than Trump
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: pic.twitter.com/cQFM07hA2F
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: 15% Joe man you are weak.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: @SenSanders @ewarren @JoeBiden @PeteButtigieg @amyklobuchar - take note.https://twitter.com/HalSparks/status/1230277513227599872 …
# Mentions: @SenSanders @ewarren @JoeBiden @PeteButtigieg @amyklobuchar
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: @JoeBiden https://twitter.com/PpollingNumbers/status/1229899200986599427 …
# Mentions: @JoeBiden
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: #BananaRepublicans
# Mentions:
# Hashtags: #BananaRepublicans
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: pic.twitter.com/uBZaCkVVxY
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Ummm I’m guessing you won’t admit you told @JoeBiden could interfere with criminal investigation in Ukraine? pic.twitter.com/NN5wvXbQze
# Mentions: @JoeBiden
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: @amyklobuchar @PeteButtigieg @JoeBiden @MikeBloomberg @ewarren @TomSteyer I hope someone calls out Bernie for his medical records tonight. #DemDebate
# Mentions: @amyklobuchar @PeteButtigieg @JoeBiden @MikeBloomberg @ewarren @TomSteyer
# Hashtags: #DemDebate
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: https://m.youtube.com/watch?v=SiaQyNJwuTg&t=14s …
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Bernie has done this with numerous votes where he chose to take a principled stance instead of cowering to political pressure. FACTS!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Poor Sully. Now Joe has drug his name into it.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 1
# Text: The rival campaigns of Bernie Sanders and Joe Biden started early, taking pre-debate shots at the former New York mayor. https://bit.ly/2T2Dzvy
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: pic.twitter.com/K0Bo5YsxMD
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Be mindful. Any smear becomes their meme. Remember what’s at stake in November and behave with respect and dignity while debating differences.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Include Michigan we riding with Joe Biden
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: pic.twitter.com/HZD9Qxy24l
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 6
# Text: @BarackObama y @JoeBiden prometieron reformar las leyes de migración y nos fallaron. Hasta separaron familias y pusieron niños en jaulas. Joe Biden hace las miasmas promesas. ¿Nos estara mintiendo otra vez? ¡Mire el video para saber mas! pic.twitter.com/pgdOSH40gO
# Mentions: @BarackObama @JoeBiden
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: I think Sully is in dementia.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: #StrictlyNonPartisan Ok Joe
# Mentions:
# Hashtags: #StrictlyNonPartisan
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Our President WAS ready on day 1. First day in office, he began immediately fixing Obama’s mess. He has done more in 3 years than you have in a lifetime for this country. He has done for US, while you did for yourself.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: in Hell!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: I dont know, I'm voting for Bloomberg!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Assist the impeachment coup. If he was not a candidate there wouldn't be grounds for the coup..
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: I would have to die.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: So old white woman are fine?
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: if you really cared about beating trump at all costs, you would back the democratic frontrunner. hoping the frontrunner loses is anti unity
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: @JoeBiden it’s time you closeup shop
# Mentions: @JoeBiden
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: As in... “But the emails!”pic.twitter.com/qL22Dp1C8r
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Yes I know that. Good point. But it's always better to resist on all fronts!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Bernie knew the sentencing guideline add-on was a horrible idea and he voted against it. He ignored the political backlash and took the vote because it was the right thing to do
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: make it make sense
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: It’s politics at its worst . Meanwhile it’s @JoeBiden who he’s complimented in a heartfelt way and we all know it #cancelhouston #ThankYouACE #AskBloomberg #MAFS #America #AbsaPrem #MCIWHU #Bernie #AmericansFindTrumpGuilty #DemDebate #DemocraticDebate #DemocracyDiesinDarkness
# Mentions: @JoeBiden
# Hashtags: #cancelhouston #ThankYouACE #AskBloomberg #MAFS #America #AbsaPrem #MCIWHU #Bernie #AmericansFindTrumpGuilty #DemDebate #DemocraticDebate #DemocracyDiesinDarkness
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: JOEMENTUM
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: “Regardless of who wins my life is good.” Lmao what privilege.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: What reality do you live in?
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: #JoeBiden will beat trump. https://twitter.com/SallyDeal4/status/1230221537019449344 …
# Mentions:
# Hashtags: #JoeBiden
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Good point! Trump has three years experience as President, you have zero!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: https://lifestyle.clickhole.com/heartbreaking-the-worst-person-you-know-just-made-a-gr-1825121606 …
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: The only thing you would be ready for is total failure. We don’t want socialism, go somewhere else with this crap. #trump2020
# Mentions:
# Hashtags: #trump2020
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Sometimes when legislation is sure to pass congress members use amendments to try and get through less popular or controversial laws that otherwise would never pass. That’s what happened here.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: WHAT GIVES? Becket Adams spots a notable name missing from the list of people trying to help resuscitate Joe Biden’s campaign https://twitchy.com/dougp-3137/2020/02/19/what-gives-becket-adams-spots-a-notable-name-missing-from-the-list-of-people-trying-to-help-resuscitate-joe-bidens-campaign/ … via @twitchyteam
# Mentions: @twitchyteam
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 4
# Text: Joe Biden trying to win a presidential election pic.twitter.com/Au6vbR6HiP
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Paid off Mafia Media by Bloomberg!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: You did 2018 lmao
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: @chucktodd @CNN @JoeBiden @ewarren let me get this straight these #Democrats will focus more on #Bloomberg instead of @SenSanders.isn't #Bernie the front runner?.. #Democrats are such #Dumbasses no wonder they still have like 50 ppl to pick from. #AmyKobachar #TomSteyer #DemDebate
# Mentions: @chucktodd @CNN @JoeBiden @ewarren @SenSanders
# Hashtags: #Democrats #Bloomberg #Bernie #Democrats #Dumbasses #AmyKobachar #TomSteyer #DemDebate
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Anti unity?? You're kidding right? YOU - of all people accuse someone of being anti-unity? Are you a parody account? Am I being punk'd?
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: I will hold my nose for Bernie But I'm thinking he might pick AOC as VP Thoughts?
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: That would be Trump
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Biden straight up coming with the fire!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Nice photo #TeamJoe
# Mentions:
# Hashtags: #TeamJoe
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 2
# Text: The MOST important poll of all - The battleground states. Vote @JoeBiden pic.twitter.com/9WvKb41rq2
# Mentions: @JoeBiden
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 1
# Text: You people are scared shitless what’s coming! @BarackObama @JoeBiden CAN STILL BE IMPEACHED! This is distraction info by MSNBC because of Burisma actors are in deep trouble! pic.twitter.com/JQEnpWdVu3
# Mentions: @BarackObama @JoeBiden
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: He's gonna go ape mode on Bloomberg tonight but say something like "my good friend Liz Warren, and my personal idol Joe Biden, are paragons of electability, and also Trump is racist"
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: used by federal judges "and would seriously impair the ability of courts to impose just and reasonable sentences."
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Bloomberg’s disturbing comments to 11-year-old girl have people calling him “Joe Biden Jr.” https://www.lifezette.com/2020/02/bloombergs-disturbing-comments-to-11-year-old-girl-have-people-calling-him-joe-biden-jr/ … via @LifeZette
# Mentions: @LifeZette
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Because ????
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 1
# Text: Joe Biden is trying another approach to appeal to the young Bernie supporters. Need to up that anger, Joe, if you are going to compete with Bernie. Let me help with that. "Where's Hunter, and how much money did he make?" pic.twitter.com/h7REiDGKuF
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 5
# Text: pic.twitter.com/jEvMezWuKR
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: That is a pretty sneaky dirty ad by Bloomberg. He kniw Biden2020 Is running as well as he is. Make sure you remind him tonight @JoeBiden
# Mentions: @JoeBiden
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 1
# Text: We love our constitution and country too much for that. #KAG!
# Mentions:
# Hashtags: #KAG
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 1
# Text: Hope #joebiden becomes prolife which is the stance of the religion he is claiming.
# Mentions:
# Hashtags: #joebiden
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: TexasforBiden2020
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# ...
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: #DemDebate tonight. Someone get these candidates November Third shirts! http://november-third.com #NevadaCaucus2020 #novemberthird #convonotconflict @JoeBiden @PeteButtigieg @MikeBloomberg @ewarren @amyklobuchar @BernieSanders @TheEllenShow @scrowder @CBS12 @Oprah @FOX29WFLXpic.twitter.com/png1YePOIk
# Mentions: @JoeBiden @PeteButtigieg @MikeBloomberg @ewarren @amyklobuchar @BernieSanders @TheEllenShow @scrowder @CBS12 @Oprah @FOX29WFLXpic
# Hashtags: #DemDebate #NevadaCaucus2020 #novemberthird #convonotconflict
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Thanks Joe!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Glad he’s now a Democrat so your words have meaning. thanks for your service...hope you fly in the polls. Seriously.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 2
# Text: Or one might say that Ukraine didn't announce an investigation of Joe Biden. The aid was released. It's all the same nowadays.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: The problem is it’s not up to Democrats, it’s the swing voters. Most dems will vote Blue no matter who. Trump supporters will vote for him. We need 8 million more swing voters than Trump and we need them and all Dems to vote
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: @JoeBiden Joe Biden has dedicated his life to this country Ukraine building a future for his son. @TrumpWarRoom @realDonaldTrump @GOP @@FoxNewspic.twitter.com/aiqieTcHMv
# Mentions: @JoeBiden @TrumpWarRoom @realDonaldTrump @GOP @ @FoxNewspic
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: He's so ignorant on the topic.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: holy shit and they say we’re toxic!! If you still haven’t admitted to yourself that Hillary Clinton was one of the single most unpopular, buzz-killing candidates in our party’s recent history you’re willfully ignorant. It’s been long established by your precious MSNBC too.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: I think that after Super Tuesday on March 3rd there will be No Malarkey bc Joe Biden will drop out of the race. He can thank the Dems in the House for throwing him under the bus!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: RIP Joe Biden https://twitter.com/Gizmodo/status/1230161060054913025 …
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: pic.twitter.com/r7A6ZzaPdT
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: The rich and big business would sure love if it was bloomberg against trump. Then they win either way.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: gorgeous!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 1
# Text: @BernieSanders @PeteButtigieg @ewarren @amyklobuchar @MikeBloomberg @JoeBiden. Care to comment tonight on the most expensive disease in America, one that has no survivors? #EndAlzhttps://twitter.com/ALZIMPACT/status/1230222522517458944 …
# Mentions: @BernieSanders @PeteButtigieg @ewarren @amyklobuchar @MikeBloomberg @JoeBiden
# Hashtags: #EndAlzhttps
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: @K_JeanPierre you commentary is dead wrong! You don't speak for the whole Democratic party. The moderate wing is a bigger wing of the party & we need Repub women support like we did in 2018 to flip the WH & seats. Bernie ain't it! @NicolleDWallace @SteveSchmidtSES @JoeBiden https://twitter.com/DeadlineWH/status/1230238178214318082 …
# Mentions: @K_JeanPierre @NicolleDWallace @SteveSchmidtSES @JoeBiden
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: @ewarren @SenSanders & @JoeBiden have All said racist comments as well as thought it about minorities from 20 years ago, I GUARANTEE it! The FACT that @MikeBloomberg has acknowledged that & apologized for it was a start, but he needs to implent policies to change the division!
# Mentions: @ewarren @SenSanders @JoeBiden @MikeBloomberg
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Be great today as only you can, live to the fullest, enjoy, get and give love...
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Comparing this situation to birtherism is a horrid take @BernieSanders (78) is not being treated differently from @JoeBiden (77) and @MikeBloomberg (78) because of his views, he had a heart attack less than 5 months ago. JB and MB did not.https://twitter.com/atrupar/status/1230120557213093890 …
# Mentions: @BernieSanders @JoeBiden @MikeBloomberg
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: POLL: If Joe Biden won the Democratic nomination, who would you vote for?
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: At least you remember his name
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Out twice. Chances are, he wont be able to win this election against Trump especially with Trump running the type of disinformation campaigns, he has planned. @JoeBiden (In MY OPINION) COULD win against Trump. I have a sinking, sick feeling, we've already lost this election &
# Mentions: @JoeBiden
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: GET HIM JOE
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: you are republina
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Thats OK Joe, we dont vote for child sniffers either, especially those thats been in office for decades and hasnt got any thing done to help us
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: You do, but we appreciate you not endorsing this one in particular.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Since when?
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: It is 257 Days until #OperationOrangeCrush IBEW! If #IBEW's #Union members choice doesn't make the cut, you've got to get the word out! NO COUCH POTATOES! #VoteBlueNoMatterWho2020
# Mentions:
# Hashtags: #OperationOrangeCrush #IBEW #Union #VoteBlueNoMatterWho2020
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: #GeorgeZimmermanIsaMurderer #NeverNRA #RIPTrayvon @JoeBiden #NRABernie #BulletBernie #Biden2020https://twitter.com/ewarren/status/1225271209903955968 …
# Mentions: @JoeBiden
# Hashtags: #GeorgeZimmermanIsaMurderer #NeverNRA #RIPTrayvon #NRABernie #BulletBernie #Biden2020https
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Well that killed this.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 2
# Text: Joe Biden has been in office for 44 yrs Chuck Schumer in office for 38 yrs Nancy Pelosi in office for 32 yrs Maxine Waters in office for 28 yrs Bernie Sanders in office for 26 yrs President Trump has been in office for 3 years And everything is his fault? Really? Idiots...
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Warren warrants your support -she'll arrest Trump. http://ahabit.com/boy Bottom line is that Elizabeth Warren is the only candidate who scares the shit out of both Trump and Bloomberg, and that's the consensus.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Ever wonder why Obama hasn't told Bloomberg to stop using clips of him to mislead people into believing he is endorsing Bloomberg? Obama threatened to step in to stop Bernie if he had to. Guess he thinks it is time.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Yeah. Biden's not my first choice, but I will HAPPILY vote for him over Bloomberg. Biden is just....status quo. If he gets the nom, 2024 someone I agree with more could get it next time. Bloomberg winning is at least as big a threat as Trump to our democracy
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: YES JOE GET HIS ASS
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: pic.twitter.com/QxjIW19zVt
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: #BernieSanders #California #BernieSanders2020 #JoeBiden #Biden2020 #Sanders2020 #ElizabethWarren #Warren2020 #PeteForAmerica #PeteButtigieg #PeteForPresident #PeteButtigieg2020 #MichaelBloomberg #JoeBiden2020 #ElizabethWarren2020 #CaliforniaPrimary…https://strehlspresidentialelection2016.wordpress.com/2020/02/19/ca-vt-senator-bernie-sanders-has-a-strong-lead-over-former-vp-joe-biden-ma-senator-elizabeth-warren-former-nyc-mayor-michael-bloomberg-former-in-mayor-pete-buttigieg-by-ppic/ …
# Mentions:
# Hashtags: #BernieSanders #California #BernieSanders2020 #JoeBiden #Biden2020 #Sanders2020 #ElizabethWarren #Warren2020 #PeteForAmerica #PeteButtigieg #PeteForPresident #PeteButtigieg2020 #MichaelBloomberg #JoeBiden2020 #ElizabethWarren2020 #CaliforniaPrimary
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Well why does he get a box and nobody else? That’s not fair, I’m sure @JoeBiden would like a box, maybe his numbers would go up then
# Mentions: @JoeBiden
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 1
# Text: Houston Congresswoman Sylvia Garcia endorses Joe Biden in presidential race https://www.houstonchronicle.com/politics/election/article/Houston-Congress-Sylvia-Garcia-endorses-Joe-Biden-15067285.php?utm_campaign=CMS%20Sharing%20Tools%20(Premium)&utm_source=t.co&utm_medium=referral …
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Well, I guess you haven’t seen the rebuttal Bloomberg ad featuring Joe Biden giving an emotional heartfelt endorsement of Mayor Bloomberg. I know,Brace yourselves. It’s uncompfortable to say the least.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: #FuckOffBloombergYouRacistPieceOfShit
# Mentions:
# Hashtags: #FuckOffBloombergYouRacistPieceOfShit
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Watch the show every day! Listen everybody Joe Biden is going to be our guy!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: It’s not that he’s nothing, with myself joe Biden just seems to fade away naturally in momentum. And it’s not bc of the accusation by trump. With Bernie Sanders he showing a more Resilience fight in his ideas and words and looks like he can go toe to toe with Trump.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Do you people not understand the distinction between a primary and a general election campaign?
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: yang was our only chance for that.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Yes, you and your leftist army have done their best to make everything a constant crisis and we're tired of it. But where you and your socialists are mistaken...is that we're tired of yall, not Trump.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Works for me
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 1
# Text: Please...please...PLEASE... @TheDemocrats ...don’t get lost in attacking each other at the debate tonight. That is nothing but a losing situation...Do what you are there to do....DEBATE the issues @JoeBiden @ewarren @amyklobuchar @MikeBloomberg @PeteButtigieg #DemocraticDebate
# Mentions: @TheDemocrats @JoeBiden @ewarren @amyklobuchar @MikeBloomberg @PeteButtigieg
# Hashtags: #DemocraticDebate
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: He's hurting Bloomberg and doesn't really damage Sanders anymore, just let him do it lmao
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Following you YES
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Too bad the national polls don’t mean too much in he electoral college.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: No, he endorsed him.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: @prairielive. Joe Biden speaks rod Blagojevich in prison arrested jail the court house with judge. https://images.app.goo.gl/DQGsYPCY7aJ4hpNM6 …
# Mentions: @prairielive
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Low bar......pic.twitter.com/wb0EPLBDxt
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: healthcare. Let me guess - lowest black unemployment. You are delusional.
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Maybe he is Cornpops Brother??? Bozo Biden what say you?? Lol @joebiden
# Mentions: @joebiden
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Dear @JoeBiden, Your enemy is @BernieSanders, NOT @MikeBloomberg! If anything, make an alliance with Mike. Thanks, A Concerned Supporter
# Mentions: @JoeBiden @BernieSanders @MikeBloomberg
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: #wakeup @ewarren @JoeBiden @amyklobuchar @PeteButtigieg ! You need to start attacking Sanders. He’s NOT a Dem (& he’s not your friend, Liz). He’s the left prong of Putin’s horseshoe play. Don’t make this debate about Bloomberg !!!
# Mentions: @ewarren @JoeBiden @amyklobuchar @PeteButtigieg
# Hashtags: #wakeup
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Joe Biden 1975 Flashback: Segregation Is Better for ‘Black Pride’ https://www.breitbart.com/politics/2019/02/04/joe-biden-1975-flashback-segregation-is-better-for-black-pride/ …
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Worst month of Joe Biden’s life
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: What in the world are you talking about? Who said anything about LGBqt? What racist?
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Please do this!
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: @JoeBiden How smart it is to go at Bloomberg while Sanders have double digit lead! You going lose if you don’t go at leased Sanders!
# Mentions: @JoeBiden
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: pic.twitter.com/i2VjlSh0XM
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: You did though. Fred Upton?
# Mentions:
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 1
# Text: What Cher said @JoeBiden time to bring the boots for Bernie & Bloomy (Esp Bernie) https://twitter.com/cher/status/1230239092878667776 …
# Mentions: @JoeBiden
# Hashtags:
#
# Get tweets by query search [Joe Biden]
# Username:
# Retweets: 0
# Text: Thank you, Mr. Biden, this is exactly the message I've wanted to hear.
# Mentions:
# Hashtags:

# %%
import sys
if sys.version_info[0] < 3:
    import got
else:
    import got3 as got

def main():

    def printTweet(descr, t):
        print(descr)
        print("Username: %s" % t.username)
        print("Retweets: %d" % t.retweets)
        print("Text: %s" % t.text)
        print("Mentions: %s" % t.mentions)
        print("Hashtags: %s\n" % t.hashtags)

    # Example 1 - Get tweets by username
    tweetCriteria = got.manager.TweetCriteria().setUsername('barackobama').setMaxTweets(1)
    tweet = got.manager.TweetManager.getTweets(tweetCriteria)[0]

    printTweet("### Example 1 - Get tweets by username [barackobama]", tweet)

    # Example 2 - Get tweets by query search
    tweetCriteria = got.manager.TweetCriteria().setQuerySearch('europe refugees').setSince("2015-05-01").setUntil("2015-09-30").setMaxTweets(1)
    tweet = got.manager.TweetManager.getTweets(tweetCriteria)[0]

    printTweet("### Example 2 - Get tweets by query search [europe refugees]", tweet)

    # Example 3 - Get tweets by username and bound dates
    tweetCriteria = got.manager.TweetCriteria().setUsername("barackobama").setSince("2015-09-10").setUntil("2015-09-12").setMaxTweets(1)
    tweet = got.manager.TweetManager.getTweets(tweetCriteria)[0]

    printTweet("### Example 3 - Get tweets by username and bound dates [barackobama, '2015-09-10', '2015-09-12']", tweet)

if __name__ == '__main__':
    main()
