# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
end = pd.read_csv('endorsements-2020.csv')
end
# Out:
#             date             position         city state  \
# 0     2017-07-28       representative          NaN    MD
# 1     2019-01-02             governor          NaN    NY
# 2     2019-01-03              senator          NaN    CA
# 3     2019-01-08              senator          NaN    DE
# 4     2019-01-12                mayor  San Antonio    TX
# 5     2019-01-21           DNC member          NaN    CA
# 6     2019-01-25           DNC member          NaN    DC
# 7     2019-01-27  lieutenant governor          NaN    CA
# 8     2019-01-27                mayor      Oakland    CA
# 9     2019-01-28       representative          NaN    CA
# 10    2019-01-29       representative          NaN    CA
# 11    2019-02-01              senator          NaN    NJ
# 12    2019-02-01             governor          NaN    NJ
# 13    2019-02-04           DNC member          NaN    SC
# 14    2019-02-06  past vice president          NaN    MN
# ...

# %%
biden = end.loc[end['endorsee'] == "Joe Biden"]
sanders = end.loc[end['endorsee'] == "Bernie Sanders"]
warren = end.loc[end['endorsee'] == "Elizabeth Warren"]
bloomberg = end.loc[end['endorsee'] == "Michael Bloomberg"]
# Out:
#         date  position  city  state  endorser  endorsee  endorser party  \
# points
# 1         46       404     0    404       404        46             404
# 2         48       209     0    209       209        48             206
# 3        125       278    47    278       278       125             275
# 5         12        34     0     34        34        12              34
# 6         10        41     0     41        41        10              41
# 8          7        29     0     29        29         7              28
# 10         1        11     0     11        11         1              11
#
#         source  order  category  body  district
# points
# 1           46      0       404     0         0
# 2           48    104       209   105         0
# 3          125     47       278     0       231
# 5           12      5        34     0         0
# 6           10      0        41     0         0
# 8            7      0        29     0         0
# ...

# %%
biden_counts = biden.groupby(["points"]).count()
biden_list = biden_counts["date"].tolist()

sanders_counts = sanders.groupby(["points"]).count()
sanders_list = sanders_counts["date"].tolist()

warren_counts = warren.groupby(["points"]).count()
warren_list = warren_counts["date"].tolist()

bloomberg_counts = bloomberg.groupby(["points"]).count()
bloomberg_list = bloomberg_counts["date"].tolist()
# Out:
#         date  position  city  state  endorser  endorsee  endorser party  \
# points
# 1          4         4     0      4         4         4               4
# 2          1         1     0      1         1         1               1
# 3         12        12     6     12        12        12              11
# 8          1         1     0      1         1         1               1
#
#         source  order  category  body  district
# points
# 1            4      0         4     0         0
# 2            1      1         1     0         0
# 3           12      6        12     0         6
# 8            1      0         1     0         0

# %%
# set width of bar
barWidth = 0.25
 
# set height of bar
bars1 = [11, 11, 5, 4]
bars2 = [11, 7, 11, 1]
bars3 = [45, 0, 13, 12]
bars4 = [6, 0, 3, 0]
bars5 = [5, 1, 1, 0]
bars6 = [3, 0, 0, 1]
bars7 = [0, 0, 0, 0]
 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x  in r2]
r4 = [x + barWidth for x in r3]

# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='Biden')
plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='Sanders')
plt.bar(r3, bars3, color='#2d7f5e', width=barWidth, edgecolor='white', label='Warren')
plt.bar(r4, bars4, color='#2d7f5e', width=barWidth, edgecolor='white', label='Bloomberg')

# Add xticks on the middle of the group bars
plt.xlabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(7)], ['1', '2', '3', '5', '6', '8', '10'])
 
# Create legend & Show graphic
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# data to plot
n_groups = 7
bars1 = [11, 11, 5, 4]
bars2 = [11, 7, 11, 1]
bars3 = [45, 0, 13, 12]
bars4 = [6, 0, 3, 0]
bars5 = [5, 1, 1, 0]
bars6 = [3, 0, 0, 1]
bars7 = [0, 0, 0, 0]

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.20
opacity = 0.8

rects1 = plt.bar(index, bars1, bars2, bars3, bars4, bars5, bars6, bars7,
alpha=opacity,
color='b',
label='Frank')

rects2 = plt.bar(index + bar_width, bars1, bars2, bars3, bars4, bars5, bars6, bars7,
alpha=opacity,
color='g',
label='Guido')

plt.xlabel('Person')
plt.ylabel('Scores')
plt.title('Scores by person')
plt.xticks(index + bar_width, ('A', 'B', 'C', 'D'))
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-fb61f8b65fed> in <module>()
#      21 alpha=opacity,
#      22 color='b',
# ---> 23 label='Frank')
#      24
#      25 rects2 = plt.bar(index + bar_width, bars1, bars2, bars3, bars4, bars5, bars6, bars7,
#
# ~/Downloads/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in bar(*args, **kwargs)
#    2773                       mplDeprecation)
#    2774     try:
# -> 2775         ret = ax.bar(*args, **kwargs)
#    2776     finally:
#    2777         ax._hold = washold
#
# ~/Downloads/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
# ...

# %%
# set width of bar
barWidth = 0.3
 
# set height of bar
bars1 = biden_list
bars2 = sanders_list
bars3 = warren_list
bars4 = bloomberg_list
 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]
r6 = [x + barWidth for x in r5]

# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='var1')
plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='var2')
plt.bar(r3, bars3, color='#2d7f5e', width=barWidth, edgecolor='white', label='var3')
plt.bar(r4, bars4, color='#2d7f5e', width=barWidth, edgecolor='white', label='var4')

# Add xticks on the middle of the group bars
plt.xlabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(4)], ['Biden', 'Sanders', 'Warren', 'Bloomberg'])
 
# Create legend & Show graphic
plt.legend()
plt.show()
