# %%
#for basic pre-processing
import pandas as pd
import numpy as np
import re
from re import sub

# %%
#for building the wordtovec model
from gensim.models.phrases import Phrases, Phraser
import multiprocessing
from gensim.models import Word2Vec
from collections import defaultdict
from time import time 
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#for sentiment analysis
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score 
from sklearn.metrics import precision_score 
from sklearn.metrics import recall_score 
from sklearn.metrics import f1_score

# %% [markdown]
# ## Pre-process the Tweets

# %%
biden_url = 'Biden Tweets - Biden_Tweets.csv'
biden_df = pd.read_csv(biden_url, error_bad_lines= False).drop(['Unnamed: 1', 'Username'], axis = 1)
biden_df.head(5)
# Out:
#                         timestamp  Retweets  \
# 0  Thu Apr 25 16:59:59 +0000 2019         0
# 1  Thu Apr 25 16:59:59 +0000 2019         0
# 2  Thu Apr 25 16:59:58 +0000 2019         0
# 3  Thu Apr 25 16:59:57 +0000 2019         0
# 4  Thu Apr 25 16:59:57 +0000 2019         0
#
#                                                 Text Mentions Hashtags  \
# 0             And, we have President Trump to thank.      NaN      NaN
# 1                         pic.twitter.com/PxypFuZzdb      NaN      NaN
# 2  The “hang em high” references were less than s...      NaN      NaN
# 3  Donald Trump Makes Joe Biden’s Point, Mocking ...      NaN      NaN
# 4  Factually speaking, that’s not accurate. Trump...      NaN      NaN
#
#    Sentiment
# 0        0.0
# 1        0.0
# 2        0.0
# 3       -1.0
# 4       -1.0

# %%
def text_to_word_list(text):

    text = str(text)
    text = text.lower()
    
    if 'pic.twitter' in text:
        text = 'empty'

    # Clean the text
    text = sub(r"[^A-Za-z0-9^,!?.\/'+]", " ", text)
    text = sub(r"\+", " plus ", text)
    text = sub(r",", " ", text)
    text = sub(r"\.", " ", text)
    text = sub(r"!", " ", text)
    text = sub(r"\?", " ", text)
    text = sub(r"'", " ", text)
    text = sub(r":", " ", text)
    text = sub(r"\s{2,}", " ", text)
    text = sub(r'http\S+', '', text)
    text = sub(r'//twitter', '', text)
    text = sub(r'//www', '', text)
    
    text = text.split()
    text = list(filter(lambda x: len(x) > 1, text))

    return text

# %%
biden_df["Cleaned_Text"] = biden_df["Text"].apply(lambda x: text_to_word_list(x))
biden_df.head(5)
# Out:
#                         timestamp  Retweets  \
# 0  Thu Apr 25 16:59:59 +0000 2019         0
# 1  Thu Apr 25 16:59:59 +0000 2019         0
# 2  Thu Apr 25 16:59:58 +0000 2019         0
# 3  Thu Apr 25 16:59:57 +0000 2019         0
# 4  Thu Apr 25 16:59:57 +0000 2019         0
#
#                                                 Text Mentions Hashtags  \
# 0             And, we have President Trump to thank.      NaN      NaN
# 1                         pic.twitter.com/PxypFuZzdb      NaN      NaN
# 2  The “hang em high” references were less than s...      NaN      NaN
# 3  Donald Trump Makes Joe Biden’s Point, Mocking ...      NaN      NaN
# 4  Factually speaking, that’s not accurate. Trump...      NaN      NaN
#
#    Sentiment                                       Cleaned_Text
# 0        0.0       [and, we, have, president, trump, to, thank]
# 1        0.0                                            [empty]
# 2        0.0  [the, hang, em, high, references, were, less, ...
# 3       -1.0  [donald, trump, makes, joe, biden, point, mock...
# 4       -1.0  [factually, speaking, that, not, accurate, tru...

# %%
def empty(text):
    is_empty = False
    if text == ['empty']:
        is_empty = True
    return is_empty

# %%
def filter_df(df):
    df["is_empty"] = df["Cleaned_Text"].apply(lambda x: empty(x))
    df_filtered = df[df["is_empty"] == False]
    final_df = df_filtered.drop(["is_empty"], axis = 1)
    return final_df

# %%
biden_df = filter_df(biden_df)

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')

# %%
#remove stop words
biden_df['Cleaned_Text'] = biden_df['Cleaned_Text'].apply(lambda x: [item for item in x if item not in stop])
biden_df
# Out:
#                             timestamp  Retweets  \
# 0      Thu Apr 25 16:59:59 +0000 2019         0
# 2      Thu Apr 25 16:59:58 +0000 2019         0
# 3      Thu Apr 25 16:59:57 +0000 2019         0
# 4      Thu Apr 25 16:59:57 +0000 2019         0
# 5      Thu Apr 25 16:59:57 +0000 2019         0
# ...                               ...       ...
# 52774  Sat Apr 11 11:49:39 +0000 2020         0
# 52776  Sat Apr 11 11:49:37 +0000 2020         0
# 52777  Sat Apr 11 11:49:36 +0000 2020         0
# 52779  Sat Apr 11 11:49:36 +0000 2020         0
# 52780  Sat Apr 11 11:49:35 +0000 2020         0
#
#                                                     Text Mentions  \
# 0                 And, we have President Trump to thank.      NaN
# 2      The “hang em high” references were less than s...      NaN
# 3      Donald Trump Makes Joe Biden’s Point, Mocking ...      NaN
# 4      Factually speaking, that’s not accurate. Trump...      NaN
# 5                                             HAAAAAA!!!      NaN
# ...                                                  ...      ...
# 52774                              #NeverBidenNeverTrump      NaN
# 52776  Yes he have to for some whom haven’t hear it b...      NaN
# 52777  No, no... this way Joe, this way........... th...      NaN
# 52779  LA voter- it literally doesn’t matter. You can...      NaN
# 52780  I think someone from Texas or Florida will be ...      NaN
#
#                     Hashtags  Sentiment  \
# 0                        NaN        0.0
# 2                        NaN        0.0
# 3                        NaN       -1.0
# 4                        NaN       -1.0
# 5                        NaN        0.0
# ...                      ...        ...
# 52774  #NeverBidenNeverTrump        NaN
# 52776                    NaN        NaN
# 52777                    NaN        NaN
# 52779                    NaN        NaN
# 52780                    NaN        NaN
#
#                                             Cleaned_Text
# 0                              [president, trump, thank]
# 2             [hang, em, high, references, less, subtle]
# 3      [donald, trump, makes, joe, biden, point, mock...
# 4      [factually, speaking, accurate, trump, accused...
# 5                                              [haaaaaa]
# ...                                                  ...
# 52774                             [neverbidennevertrump]
# 52776  [yes, hear, wise, reasonable, know, news, outl...
# 52777                           [way, joe, way, kitchen]
# 52779  [la, voter, literally, matter, stay, home, res...
# 52780       [think, someone, texas, florida, picked, vp]
#
# [47100 rows x 7 columns]

# %% [markdown]
# ## Create the Word2Vec Model
# _Link:_ https://www.kaggle.com/pierremegret/gensim-word2vec-tutorial

# %%
#Word2Vec takes in a list of lists 
sent = list(biden_df['Cleaned_Text'])
sent
# Out:
# [['president', 'trump', 'thank'],
#  ['hang', 'em', 'high', 'references', 'less', 'subtle'],
#  ['donald',
#   'trump',
#   'makes',
#   'joe',
#   'biden',
#   'point',
#   'mocking',
#   'candidate',
#   'intelligence',
#   'dems',
#   'sick',
#   'de',
#   'yahoo',
#   'com/entertainment/donald',
#   'trump',
#   'makes',
#   'joe',
#   'biden',
#   '130340726',
#   'html',
#   'tsrc',
#   'fauxdal'],
#  ['factually',
#   'speaking',
#   'accurate',
#   'trump',
#   'accused',
#   'nearly',
#   'two',
#   'dozen',
#   'incidents',
#   'sexual',
#   'misconduct',
#   'including',
#   'rape',
#   'one',
#   'accused',
#   'biden',
#   'anything',
#   'sexual',
#   'far',
#   'businessinsider',
#   'com/women',
#   'accused',
#   'trump',
#   'sexual',
#   'misconduct',
#   'list',
#   '2017',
#   '12'],
#  ['haaaaaa'],
#  ['asking',
#   'joe',
#   'biden',
#   'intelligence',
#   'president',
#   'sits',
#   'white',
#   'house',
#   'stupid',
#   'grin',
#   'face',
#   'trump',
#   'intelligence',
#   'president',
#   'yet'],
#  ['us', 'people', 'elected', 'trump'],
#  ['donald',
#   'trump',
#   'jr',
#   'wins',
#   'internet',
#   'thumping',
#   'creepy',
#   'uncle',
#   'joe',
#   'biden',
#   'big',
#   'michael',
#   'avenatti',
#   'endorsement',
#   'thegatewaypundit',
#   'com/2019/04/donald',
#   'trump',
#   'jr',
#   'wins',
#   'internet',
#   'thumping',
#   'creepy',
#   'uncle',
#   'joe',
#   'biden',
#   'big',
#   'michael',
#   'avenatti',
#   'endorsement/',
#   'via',
#   'gatewaypundit'],
#  ['time', 'run', 'joe'],
#  ['cares'],
#  ['trying', 'get', 'rid', 'establishment', 'rulers'],
#  ['knowing',
#   'biden',
#   'knew',
#   'was/is',
#   'shame',
#   'parents',
#   'put',
#   'pedo',
#   'creep',
#   'place',
#   'office',
#   'would',
#   'placing',
#   'dirty',
#   'hands',
#   'child',
#   'real',
#   'quick',
#   'like',
#   'camera',
#   'camera'],
#  ['nan'],
#  ['hate',
#   'half',
#   'people',
#   'america',
#   'child',
#   'consumed',
#   'hate',
#   'consumed',
#   'sad'],
#  ['speech', 'much', 'better'],
#  ['yes', 'whoever', 'vs', 'trump', 'joe', 'seems', 'better', 'person'],
#  ['please',
#   'ask',
#   'tragic',
#   'crime',
#   'bill',
#   'anita',
#   'hill',
#   'sucks',
#   'corporatist',
#   'creep',
#   'woman',
#   'girls'],
#  ['joebiden',
#   'nbc',
#   'abc',
#   'cbs',
#   'cnn',
#   'stop',
#   'telling',
#   'lies',
#   'americans',
#   'know',
#   'truth',
#   'com/scottadamssays/status/1121385145758412800'],
#  ['wish',
#   'could',
#   'donate',
#   'campaign',
#   'live',
#   'canada',
#   'allowed',
#   'donate',
#   'however',
#   'anything',
#   'reaching',
#   'american',
#   'working',
#   'living',
#   'canada',
#   'get',
#   'vote',
#   'let',
#   'know'],
#  ['late',
#   'senator',
#   'john',
#   'mccain',
#   'family',
#   'support',
#   'former',
#   'vice',
#   'president',
#   'joe',
#   'biden',
#   '2020',
#   'election',
#   'theepochtimes',
#   'com/mccain',
#   'family',
#   'support',
#   'biden',
#   'trump',
#   '2020',
#   'campaign',
#   '2893307',
#   'html',
#   'via',
#   'epochtimes'],
#  ['sleepy',
#   'joe',
#   'biden',
#   'one',
#   'msm',
#   'picture',
#   'release',
#   'touching',
#   'children',
#   'becoming',
#   'creepy',
#   'joe',
#   'biden',
#   'potus',
#   'tweet',
#   'political',
#   'killshot',
#   'ridinwithbiden',
#   'maga',
#   'com/catturd2/status/1121561568863510531'],
#  ['joe',
#   'biden',
#   'also',
#   'lies',
#   'whether',
#   'family',
#   'killed',
#   'drunk',
#   'driver',
#   'com/mitchellvii/status/1121507614775488512'],
#  ['threw',
#   'away',
#   '500',
#   'save',
#   'money',
#   'clear',
#   'win',
#   'th',
#   'dem',
#   'primary',
#   'joebiden',
#   'wash',
#   'debates',
#   'summer'],
#  ['barackobama'],
#  ['everyone', 'sure', 'bookmark', 'pull', 'needed', 'months'],
#  ['joebiden',
#   'worse',
#   'barackobama',
#   'obama',
#   'allowed',
#   'assad',
#   'kill',
#   '500',
#   '000',
#   'syrians',
#   'biden',
#   'sign',
#   'agreement',
#   'give',
#   'syria',
#   'russia',
#   'iran'],
#  ['former',
#   'vice',
#   'president',
#   'joe',
#   'biden',
#   'jumps',
#   'white',
#   'house',
#   'race',
#   'washingtonpost',
#   'com/politics/former',
#   'vice',
#   'president',
#   'joe',
#   'biden',
#   'jumps',
#   'white',
#   'house',
#   'race/2019/04/25/093ff596',
#   '0aef',
#   '11e9',
#   '88e3',
#   '989a3e456820',
#   'story',
#   'html'],
#  ['joe',
#   'biden',
#   'endorsed',
#   'michael',
#   'avenatti',
#   'launching',
#   '2020',
#   'bid',
#   'enthusiastic',
#   'support',
#   'foxnews',
#   'com/politics/joe',
#   'biden',
#   'michael',
#   'avenatti',
#   '2020',
#   'support'],
#  ['prove',
#   'fact',
#   'unemployment',
#   'rate',
#   'left',
#   'office',
#   'website',
#   'would',
#   'trust',
#   'last',
#   'checked',
#   'folks',
#   'scream',
#   'fake',
#   'news',
#   'everything'],
#  [],
#  ['loathe', 'joe', 'biden'],
#  ['vice',
#   'president',
#   'joe',
#   'biden',
#   'cannot',
#   'say',
#   'worried',
#   'soul',
#   'country',
#   'yet',
#   'wait',
#   '28',
#   'years',
#   'call',
#   'anita',
#   'hill',
#   'apologize',
#   'disingenuous',
#   'anitahill',
#   'joebiden',
#   'metoo',
#   '2020elections'],
#  ['nope'],
#  ['joe', 'scratch', 'sniff', 'biden'],
#  ['fool',
#   '20',
#   'years',
#   'ago',
#   'believe',
#   'women',
#   'allow',
#   'anything',
#   'rich',
#   'man',
#   'trying',
#   'tell',
#   'billy',
#   'bush',
#   'never',
#   'said',
#   'women'],
#  ['true',
#   'already',
#   'started',
#   'eating',
#   'turns',
#   'time',
#   'negative',
#   'ads',
#   'within',
#   'party'],
#  ['cash', 'sent', 'morning', 'next', 'week'],
#  ['kidding',
#   'realdonaldtrump',
#   'joe',
#   'biden',
#   'intelligence',
#   'integrity',
#   'morality',
#   'experience',
#   'compassion',
#   'concern',
#   'american',
#   'people',
#   'people',
#   'outside',
#   'usa',
#   'given',
#   'day',
#   'shallow',
#   'immature',
#   'lacking',
#   'intellect',
#   'gotta',
#   'go'],
#  ['nan'],
#  ['call', 'someone', 'liar', 'read', 'statements', 'carefully'],
#  ['joebiden', 'apologized', 'white', 'old', 'born'],
#  ['still',
#   'despise',
#   'way',
#   'joe',
#   'biden',
#   'treated',
#   'justice',
#   'clarence',
#   'thomas',
#   'looney',
#   'accusations',
#   'thrown',
#   'anita',
#   'hill',
#   'almost',
#   'copy',
#   'kavanaugh',
#   'hearings',
#   'com/realmagasteve/status/1121423874095222789'],
#  ['look',
#   'said',
#   'whole',
#   'presidency',
#   'joe',
#   'biden',
#   'obama',
#   'insurance',
#   'policy',
#   'would',
#   'make',
#   'end',
#   'term',
#   'knew',
#   'nobody',
#   'wants',
#   'biden',
#   'presidency',
#   'simple'],
#  ['joe',
#   'biden',
#   'worry',
#   'battle',
#   'soul',
#   'corruption',
#   'committed',
#   'vice',
#   'president',
#   'instead',
#   'worrying',
#   'battle',
#   'soul',
#   'nation'],
#  ['wonder', '100', 'yet'],
#  ['biden',
#   'son',
#   'got',
#   'chinese',
#   'financial',
#   'deal',
#   'really',
#   'belonged',
#   'joe',
#   'biden',
#   'makes',
#   'joe',
#   'biden',
#   'criminal',
#   'money',
#   'launderer',
#   'son',
#   'makes',
#   'manchurian',
#   'candidate',
#   'en',
#   'persona',
#   'since',
#   'obama',
#   'years',
#   'lying',
#   'perverted',
#   'sob'],
#  ['barf'],
#  ['joebiden',
#   'hairsniffing',
#   'racist',
#   'com/charliekirk11/status/1121529539081850881'],
#  ['donation', 'joe'],
#  ['realization',
#   'afternoon',
#   'joe',
#   'biden',
#   'apologizing',
#   'anita',
#   'hill',
#   'demands',
#   'least',
#   'eyebrow',
#   'raise',
#   'justice',
#   'clarence',
#   'thomas'],
#  ['said', 'today', 'wants', 'make', 'america', 'great'],
#  ['joe', 'biden', 'going', 'ruin', 'barack', 'legacy'],
#  ['feed'],
#  ['yesss',
#   'joe',
#   'biden',
#   'needs',
#   'apologize',
#   'people',
#   'anita',
#   'hill',
#   'said',
#   'new',
#   'york',
#   'times',
#   'interview',
#   'clarence',
#   'thomas',
#   'hearing',
#   '1991',
#   'huffpost',
#   'com/entry/anita',
#   'hill',
#   'joe',
#   'biden',
#   'apology',
#   '5cc217afe4b05f4d35fd999d',
#   'ncid',
#   'engmodushpmg00000004',
#   'via',
#   'huffpostpol'],
#  [],
#  ['much',
#   'left',
#   'gatekeeper',
#   'seeing',
#   'people',
#   'refer',
#   'criticism',
#   'joe',
#   'biden',
#   'left',
#   'devouring',
#   'amazing'],
#  ['lmao', 'yea', 'give', 'politician', 'money'],
#  ['whole',
#   'charlottesville',
#   'thing',
#   'available',
#   'cspan',
#   'trump',
#   'say',
#   'media',
#   'democrats',
#   'keep',
#   'repeating',
#   'either',
#   'really',
#   'stupid',
#   'dishonest',
#   'span',
#   'org/video/',
#   '432633',
#   '1/president',
#   'trump',
#   'blame',
#   'sides',
#   'violence',
#   'charlottesville'],
#  ['0for3joe2020'],
#  ['oh',
#   'great',
#   'another',
#   'biased',
#   'person',
#   'panel',
#   'another',
#   'reason',
#   'watching'],
#  ['joe', 'biden', 'suck', 'dick'],
#  ['michelle',
#   'real',
#   'candidate',
#   'parade',
#   'conservative',
#   'media',
#   'shredded',
#   'low',
#   'level',
#   'dem',
#   'fools'],
#  ['//youtu',
#   'be/k4xmvwirmx0',
#   'listen',
#   'audio',
#   '39',
#   'idea',
#   'horny',
#   'let',
#   'fill',
#   'gaps',
#   'thanks',
#   'running',
#   'ad',
#   'timeline',
#   'glad',
#   'got',
#   'chance',
#   'show',
#   'would',
#   'biden',
#   'voters',
#   'trump2020',
#   'walkaway',
#   'lgbtexit',
#   'nobiden'],
#  ['name', 'one', 'dictator', 'lined', 'pockets'],
#  ['hey', 'joebiden', 'wtf', 'com/realsaavedra/status/1121449213773139971'],
#  ['tweet',
#   'priority',
#   'becoming',
#   'viable',
#   'candidate',
#   'actually',
#   'came',
#   'bidens',
#   'campaign',
#   'needs',
#   'fire',
#   'whoever',
#   'came',
#   'shit',
#   'start'],
#  ['president', 'trump', 'maga', 'crazy', 'joe', 'daa', 'destroy', 'america'],
#  ['joebiden', 'call', 'dastardlydonnie'],
#  ['world', 'hates', '45'],
#  ['assuming', 'gop', 'nominate', 'trump', 'believe', 'given'],
#  ['joe', 'biden'],
#  ['check', 'outretw', 'http', '//bit', 'ly/2w9z17c'],
#  ['joe',
#   'biden',
#   'confused',
#   'catholicism',
#   'catholicvote',
#   'org/joe',
#   'bidens',
#   'confused',
#   'catholicism/',
#   'via',
#   'catholicvote'],
#  ['joe',
#   'biden',
#   'win',
#   'nomination',
#   'presidency',
#   'liberals',
#   'ignore',
#   '10',
#   'side',
#   'gets',
#   '90',
#   'press',
#   'biden',
#   'polls',
#   'well',
#   'appeals',
#   'rest',
#   'us',
#   'get',
#   'lumped',
#   'woke',
#   'think',
#   'straight',
#   'biden2020'],
#  ['netneutrality'],
#  ['michael',
#   'avenatti',
#   'endorses',
#   'joe',
#   'biden',
#   'president',
#   'breitbart',
#   'com/politics/2019/04/25/michael',
#   'avenatti',
#   'endorses',
#   'joe',
#   'biden',
#   'president/'],
#  ['already', 'rolling', 'total', 'lie', 'manipulation', 'events', 'wow'],
#  ['joe', 'biden', 'run', 'president', 'millennialchemist2020'],
#  ['joebiden',
#   'thank',
#   'man',
#   'integrity',
#   'honor',
#   'respect',
#   'american',
#   'people',
#   'constitution',
#   'worldwide',
#   'diplomacy',
#   'strength',
#   'back',
#   'nomoretrump',
#   'nomorelies'],
#  ['joe',
#   'biden',
#   'kinds',
#   'haves',
#   'president',
#   'trump',
#   'orange',
#   'glow',
#   'still',
#   'enough',
#   'get',
#   'elected',
#   'must',
#   'trump',
#   'putting',
#   'america',
#   'americans',
#   'first',
#   'trump',
#   '2016',
#   'win',
#   '2020',
#   'americafirst',
#   'maga2020'],
#  ['touching', 'add'],
#  ['anyone',
#   'still',
#   'pittsburgh',
#   'monday',
#   'joe',
#   'biden',
#   'rally',
#   'click',
#   'link',
#   'details',
#   'mobilize',
#   'us/joebiden/event/91133/'],
#  ['love',
#   'joebiden',
#   'love',
#   'nfldraft',
#   'great',
#   'day',
#   'many',
#   'dreams',
#   'mine',
#   'others',
#   'coming',
#   'true',
#   'nfldraft',
#   'bidenforpresident'],
#  ['let', 'go', 'joe'],
#  ['joe',
#   'biden',
#   'believing',
#   'asking',
#   'permission',
#   'women',
#   'heather',
#   'heyer',
#   'family',
#   'different',
#   'neverbiden',
#   'thedailybeast',
#   'com/heather',
#   'heyers',
#   'mom',
#   'susan',
#   'bro',
#   'breaks',
#   'silence',
#   'biden',
#   'invoking',
#   'charlottesville',
#   '2020'],
#  ['bern', 'establishment'],
#  ['students',
#   'shocked',
#   'footage',
#   'joe',
#   'biden',
#   'touching',
#   'women',
#   '//youtu',
#   'be/czotibeqrey',
#   'via',
#   'youtube'],
#  ['actually', 'thought', 'made', 'case', 'pres', 'trump'],
#  ['going',
#   'need',
#   'see',
#   'joebiden',
#   'wrote',
#   'yearbook',
#   '16',
#   'make',
#   'ruling'],
#  ['let',
#   'creepy',
#   'joe',
#   'grope',
#   'publically',
#   'switch',
#   'parties',
#   'dems',
#   'dont',
#   'want'],
#  ['joe', 'biden', 'also', 'enemy', 'things', 'rue'],
#  ['go',
#   'away',
#   'joe',
#   'disqualified',
#   'decades',
#   'ago',
#   'anita',
#   'hill',
#   'bussing',
#   'voting',
#   'wars',
#   'zionist',
#   'weakening',
#   'gun',
#   'banking',
#   'laws',
#   'supporting',
#   'racist',
#   'war',
#   'drugs',
#   'mass',
#   'incarceration',
#   'making',
#   'bankruptcy',
#   'harder',
#   'tepid',
#   'clinton',
#   'esque',
#   'triangulation',
#   'fail',
#   'enough'],
#  ['joe',
#   'biden',
#   'says',
#   'trump',
#   'worst',
#   'thing',
#   'lifetime',
#   'list',
#   'much',
#   'worse',
#   'http',
#   '//dlvr',
#   'it/r3wpjd'],
#  ['hahahahahahahahaha', 'nah', 'dude', 'good', 'thanks'],
#  ['joe',
#   'biden',
#   'fraud',
#   'plain',
#   'simple',
#   'truthdig',
#   'com/articles/joe',
#   'biden',
#   'phony',
#   'plain',
#   'simple/',
#   'norman',
#   'solomon',
#   'usa',
#   'uk',
#   'eu',
#   'bds'],
#  ['sleepy', 'joe'],
#  ['give', 'another', 'day', 'think'],
#  ['choosing',
#   'wine',
#   'analogy',
#   'wines',
#   'turn',
#   'vinegar',
#   'age',
#   'yes',
#   'experience',
#   'see',
#   'many',
#   'septuagenarians',
#   'becoming',
#   'ceos',
#   'top',
#   'companies',
#   'even',
#   'staying',
#   'ceos',
#   'age',
#   'age',
#   'problem',
#   'lot',
#   'people'],
#  ['joebiden',
#   'plagiarized',
#   'speech',
#   'john',
#   'kennedy',
#   'first',
#   'presidential',
#   'run',
#   'think',
#   'speech',
#   'jfk',
#   'time',
#   'joe'],
#  ['campaign',
#   'claims',
#   'joe',
#   'biden',
#   'asked',
#   'obama',
#   'endorse',
#   'breitbart',
#   'com/politics/2019/04/25/campaign',
#   'claims',
#   'joe',
#   'biden',
#   'asked',
#   'obama',
#   'endorse',
#   'him/'],
#  ['joe',
#   'biden',
#   'campaign',
#   'ex',
#   'boyfriend',
#   'trying',
#   'win',
#   'back',
#   'com/olivianuzzi/status/1121533083310788610'],
#  ['restore',
#   'soul',
#   'mean',
#   'restore',
#   'high',
#   'unemployment',
#   'rate',
#   'high',
#   'tax',
#   'rates',
#   'high',
#   'illegal',
#   'immigration',
#   'thanks',
#   'joe'],
#  ['cool', 'could', 'supported', 'next', 'generation', 'leaders'],
#  ['oops',
#   'someone',
#   'know',
#   'means',
#   'example',
#   'please',
#   'see',
#   'gillebrand',
#   'funding',
#   'tweet'],
#  ['weak',
#   'sauce',
#   'joe',
#   'biden',
#   'picks',
#   'support',
#   'prominent',
#   'georgia',
#   'democrat',
#   'ajc',
#   'com/blog/politics/joe',
#   'biden',
#   'picks',
#   'support',
#   'prominent',
#   'georgia',
#   'democrat/i0rr5fyzoml49jvhjyafip/'],
#  ['joe',
#   'biden',
#   '2020',
#   'platform',
#   'multiculturalism',
#   '//youtu',
#   'be/aeg1wuoa2hs'],
#  ['wow',
#   'read',
#   'mr',
#   'grabby',
#   'hands',
#   'joe',
#   'biden',
#   'asked',
#   'worst',
#   'potus',
#   'ever',
#   'obama',
#   'endorse',
#   'michael',
#   'avenatti',
#   'wow',
#   'readdonaldtrump',
#   'deep',
#   'trouble'],
#  ['thanks', 'god'],
#  ['video',
#   'show',
#   'questions',
#   'joebiden',
#   'blame',
#   'joe',
#   'biden',
#   'question',
#   'asked',
#   'republicans',
#   'one',
#   'blames',
#   'dianne',
#   'feinstein',
#   'kavanaugh'],
#  ['man',
#   'constitutionally',
#   'incapable',
#   'apologizing',
#   'correctly',
#   'joe',
#   'biden',
#   'cannot',
#   'trusted',
#   'neither',
#   'tactician',
#   'ally'],
#  ['sure',
#   'said',
#   'core',
#   'values',
#   'nation',
#   'stake',
#   'one',
#   'thing',
#   '100',
#   'agree',
#   'joe',
#   'nation',
#   'cannot',
#   'stand',
#   'one',
#   'day',
#   'democratic',
#   'leadership',
#   'one',
#   'single',
#   'day'],
#  ['could',
#   'agree',
#   'race',
#   'stands',
#   'far',
#   'nomination',
#   'biden/harris',
#   'ticket',
#   'looks',
#   'strong',
#   'keep',
#   'mind',
#   'never',
#   'fully',
#   'satisfy',
#   'left',
#   'fringe',
#   'party',
#   'find',
#   'way',
#   'make',
#   'sure',
#   'stay',
#   'home',
#   'hearing',
#   'bernie',
#   'brigade'],
#  ['really',
#   'really',
#   'anyone',
#   'believe',
#   'joebiden',
#   'take',
#   'good',
#   'look',
#   'sleepy',
#   'joe',
#   'puts',
#   'hands',
#   'little',
#   'girls',
#   'guy',
#   'sick',
#   'com/w',
#   'terrence/status/1121511163286704128',
#   '21'],
#  ['got'],
#  ['forget',
#   'trump',
#   'came',
#   'wave',
#   'obama',
#   'biden',
#   'created',
#   'facts',
#   'change',
#   'fit',
#   'narrative',
#   'must',
#   'frightened',
#   'joebiden'],
#  ['done'],
#  ['dear',
#   'joebiden',
#   'please',
#   'make',
#   'early',
#   'announcement',
#   'president',
#   'obama',
#   'running',
#   'mate',
#   'win',
#   'primary',
#   'drive',
#   'trump',
#   'completely',
#   'fucking',
#   'bananas',
#   'us',
#   'need',
#   'love',
#   'america'],
#  ['former',
#   'vp',
#   'joe',
#   'biden',
#   'announces',
#   '2020',
#   'presidential',
#   'bid',
#   'com/i/events/1121355811064700928'],
#  ['got',
#   'caught',
#   'cheating',
#   'school',
#   'wooopty',
#   'dooooo',
#   'cracked',
#   'huge',
#   'story'],
#  ['safe', 'travels', 'ana'],
#  ['old', 'hair', 'sniffer'],
#  ['donald',
#   'trump',
#   'jr',
#   'wins',
#   'internet',
#   'thumping',
#   'creepy',
#   'uncle',
#   'joe',
#   'biden',
#   'big',
#   'michael',
#   'avenatti',
#   'endorsement',
#   'thegatewaypundit',
#   'com/2019/04/donald',
#   'trump',
#   'jr',
#   'wins',
#   'internet',
#   'thumping',
#   'creepy',
#   'uncle',
#   'joe',
#   'biden',
#   'big',
#   'michael',
#   'avenatti',
#   'endorsement/',
#   'via',
#   'gatewaypundit'],
#  ['solutions',
#   'attributed',
#   'joe',
#   'biden',
#   'successes',
#   'mr',
#   'trump',
#   'lived',
#   'also',
#   'president'],
#  ['ikr', 'comeback', 'america'],
#  ['need', '00', 'anyone', 'billion', 'ukraine'],
#  ['go',
#   'another',
#   'white',
#   'old',
#   'genocide',
#   'owner',
#   'nothing',
#   'else',
#   'addictive',
#   'matters',
#   'wrong',
#   'addicted',
#   'nicotine',
#   'bet',
#   'buddy',
#   'bill',
#   'clinton',
#   'told',
#   'say',
#   'reversechapter'],
#  ['clear', 'fuck', 'joebiden', 'joe2020'],
#  ['good',
#   'thread',
#   'true',
#   'anyone',
#   'thinks',
#   'biden',
#   'could',
#   'gotten',
#   'clarence',
#   'thomas',
#   'confirmed',
#   'without',
#   'republican',
#   'help',
#   'kidding'],
#  ['say',
#   'biden',
#   'voted',
#   'thomas',
#   'handling',
#   'anita',
#   'hill',
#   'hearings',
#   'helped',
#   'confirm',
#   'thomas',
#   'biden',
#   'allowed',
#   'hill',
#   'witnesses',
#   'testify',
#   'thomas',
#   'may',
#   'confirmed',
#   'worse',
#   'yet',
#   'biden',
#   'abandoned',
#   'brave',
#   'woman',
#   'hill',
#   'never',
#   'forgiven'],
#  ['joe',
#   'biden',
#   'championed',
#   '1994',
#   'criminal',
#   'bill',
#   'locked',
#   'poor',
#   'soul',
#   'trump',
#   'reversed',
#   'freeing',
#   'dbongino'],
#  ['rob',
#   'reiner',
#   'endorses',
#   'joe',
#   'biden',
#   'restore',
#   'souls',
#   'standing',
#   'leader',
#   'free',
#   'world',
#   'breitbart',
#   'com/entertainment/2019/04/26/rob',
#   'reiner',
#   'endorses',
#   'joe',
#   'biden',
#   'hell',
#   'restore',
#   'souls',
#   'standing',
#   'leader',
#   'free',
#   'world/'],
#  ['end',
#   'gets',
#   'attention',
#   'gets',
#   'bend',
#   'ear',
#   'listen',
#   'whose',
#   'counsel',
#   'seek',
#   'grassroots',
#   'donors',
#   'comcast',
#   'mega',
#   'donors',
#   'ways',
#   'today',
#   'democrats',
#   'progressives',
#   'independents',
#   'favor',
#   'grassroots'],
#  ['joebiden', 'fired', 'ready', 'go', 'teambiden'],
#  ['forget', 'terrible', 'candidate', 'beat', 'trump', 'delusional'],
#  ['wait', 'let', 'get', 'piggy', 'bank'],
#  ['well', 'said', 'bottom', 'line', 'facts'],
#  ['chance', 'hell', 'never', 'vote', 'democrat'],
#  ['news',
#   'get',
#   'msnbc',
#   'cnn',
#   'hardball',
#   'son',
#   'got',
#   'fired',
#   'joe',
#   'biden',
#   'forced',
#   'ukraine',
#   'sack',
#   'prosecutor',
#   'general',
#   'six',
#   'hours',
#   'via',
#   'russian',
#   'rt',
#   'com',
#   'world',
#   'news',
#   'interesting',
#   'matthews',
#   'documentary',
#   'biden',
#   'tcot',
#   'maga',
#   'rt',
#   'com/news/416888',
#   'biden',
#   'fire',
#   'ukrainian',
#   'prosecutor/'],
#  ['joebiden',
#   'presisidentobams',
#   'vp',
#   'years',
#   'barackobama',
#   'said',
#   'best',
#   'vice',
#   'president',
#   'ever',
#   'yet',
#   'biden',
#   'asked',
#   'obama',
#   'endorse',
#   'crock',
#   'shit',
#   'like',
#   'saying',
#   'stepped',
#   'right',
#   'gonna',
#   'fire',
#   'ass'],
#  ['talking', 'creepy', 'uncle', 'joe'],
#  ['long', 'joe', 'biden', 'campaign', 'hacked'],
#  ['like', 'yrs', 'hands', 'ropes', 'young', 'progressive'],
#  ['joe',
#   'biden',
#   '2020',
#   'ukrainian',
#   'nightmare',
#   'closed',
#   'probe',
#   'revived',
#   '//thehill',
#   'com/opinion/white',
#   'house/436816',
#   'joe',
#   'bidens',
#   '2020',
#   'ukrainian',
#   'nightmare',
#   'closed',
#   'probe',
#   'revived',
#   'xmoba9xing8',
#   'twitter'],
#  ['nan'],
#  ['may', 'want', 'check', 'miracle', 'bank', 'balance'],
#  ['fuck', 'forever', 'joe', 'biden'],
#  ['glad',
#   'appreciate',
#   'grass',
#   'roots',
#   'donors',
#   'accepting',
#   'money',
#   'lobbyists',
#   'billionaires',
#   'otherwise',
#   'start',
#   'bashing',
#   'things',
#   'like',
#   'free',
#   'college',
#   'medicare',
#   'sure',
#   'working'],
#  ['yawn', 'next'],
#  ['hard', 'pass'],
#  ['joebiden',
#   'dnc',
#   'rnc',
#   'democrat',
#   'presidential',
#   'hopefuls',
#   'use',
#   'information',
#   'biden',
#   'ukraine',
#   'dem',
#   'hopefuls',
#   'pull',
#   'stops',
#   'biden',
#   'com/terri904/status/1121925173370859520'],
#  ['vote',
#   'democrat',
#   'vs',
#   'trump',
#   'think',
#   'dem',
#   'beat',
#   'trump',
#   'joe',
#   'biden'],
#  ['cummies', '5dlorrs'],
#  ['way',
#   'vote',
#   'joebiden',
#   'ends',
#   'bare',
#   'knuckle',
#   'brawl',
#   'death',
#   'realdonaldtrump',
#   'com/reuters/status/1121919384904183808'],
#  [],
#  ['democrat', 'establishment', 'thanks'],
#  ['fan',
#   'trump',
#   'stop',
#   'laughing',
#   'gif',
#   'touch',
#   'sniff',
#   'joebiden',
#   'com/realdonaldtrump/status/1113862077842640898'],
#  ['guy', 'real'],
#  ['nope'],
#  ['joe',
#   'biden',
#   'running',
#   'president',
#   'like',
#   'nbc',
#   'made',
#   'friends',
#   'spin',
#   'show',
#   'ross',
#   'problematic',
#   'relevant',
#   'associated',
#   'people',
#   'actually',
#   'liked'],
#  ['side', 'republicans', 'stand', 'trump', 'would', 'want', 'alienate'],
#  ['nation',
#   'reflected',
#   'president',
#   'give',
#   'thought',
#   'compare',
#   'outcome',
#   'nation',
#   'spirit',
#   'decent',
#   'honest',
#   'human',
#   'like',
#   'obama',
#   'indecent',
#   'dishonest',
#   'like',
#   'trump'],
#  ['joebiden',
#   'realize',
#   'stupid',
#   'look',
#   'since',
#   'botox',
#   'face',
#   'lift',
#   'skin',
#   'tight',
#   'hardly',
#   'see',
#   'eyelids',
#   'also',
#   'lived',
#   'thru',
#   'scandals',
#   'leftie',
#   'lunatic',
#   'libs',
#   'might',
#   'dumb',
#   'enough',
#   'believe',
#   'would',
#   'prove',
#   'low',
#   'iq',
#   'com/dbongino/status/1121888972207206401'],
#  ['biden', 'vp', 'quo', 'jussie', 'smollett', 'hahaha'],
#  ['never'],
#  ['jimmy',
#   'reacts',
#   'joe',
#   'biden',
#   'finally',
#   'announcing',
#   'running',
#   'president',
#   '//youtu',
#   'be/gwkt48srjvk',
#   'via',
#   'youtube'],
#  ['maybe',
#   'joebiden',
#   'give',
#   'read',
#   'canada',
#   'ca/content/dam/hc',
#   'sc/healthy',
#   'canadians/migration/task',
#   'force',
#   'marijuana',
#   'groupe',
#   'etude/framework',
#   'cadre/alt/framework',
#   'cadre',
#   'eng',
#   'pdf',
#   'com/marijuanamoment/status/1121435168655458304'],
#  ['idk', 'want', 'vote', 'joe', 'biden'],
#  ['order',
#   'get',
#   'angry',
#   'angry',
#   'hillary',
#   'accounts',
#   '2020',
#   'acknowlege',
#   'dont',
#   'really',
#   'know',
#   'people',
#   'dont',
#   'end',
#   'bitter'],
#  ['picture', 'makes', 'nauseous'],
#  ['sad',
#   'think',
#   'many',
#   'people',
#   'must',
#   'hugged',
#   'touched',
#   'life',
#   'handful',
#   'people',
#   'uncomfortable',
#   'making',
#   'issue'],
#  ['watched',
#   'joebiden',
#   'interview',
#   'today',
#   'half',
#   'ass',
#   'apologies',
#   'turn',
#   'us',
#   'humans',
#   'simply',
#   'apologize',
#   'come',
#   'uncle',
#   'joe',
#   'better',
#   'joebiden',
#   'theview'],
#  ['joe',
#   'biden',
#   'running',
#   'portrays',
#   'trump',
#   'neo',
#   'nazi',
#   'sympathizer',
#   'top',
#   'headline',
#   'thenewamerican',
#   'com/usnews/politics/item/32132',
#   'top',
#   'headline',
#   'christian',
#   'gomez',
#   'joe',
#   'biden',
#   'running',
#   'portrays',
#   'trump',
#   'neo',
#   'nazi',
#   'sympathizer',
#   'wow',
#   'biden',
#   'starts',
#   'next',
#   'presidential',
#   'campaign',
#   'lie',
#   'surprise',
#   'really'],
#  ['thoughts'],
#  ['joe',
#   'biden',
#   'raised',
#   'first',
#   'day',
#   'contributions',
#   'democratic',
#   'rivals',
#   'http',
#   '//itechnews',
#   'ml/2019/04/26/joe',
#   'biden',
#   'raised',
#   'first',
#   'day',
#   'contributions',
#   'democratic',
#   'rivals/'],
#  ['big', 'deal', 'maga'],
#  ['trumps',
#   'traitor',
#   'great',
#   'american',
#   'economy',
#   'getting',
#   'us',
#   '18',
#   'year',
#   'war',
#   'great',
#   'employment',
#   'numbers',
#   'great',
#   'interest',
#   'rates',
#   'growth',
#   'last',
#   'quarter',
#   'rebuilding',
#   'military',
#   'false',
#   'investigation',
#   'one',
#   'potus',
#   'done',
#   'think'],
#  ['joe',
#   'biden',
#   'campaign',
#   'going',
#   'end',
#   'well',
#   'whenever',
#   'end',
#   'comes',
#   'com/marijuanamoment/status/1121435168655458304'],
#  ['cannot',
#   'wait',
#   'joebiden',
#   'reminded',
#   'scandals',
#   'barackobama',
#   'seem',
#   'wiped',
#   'minds'],
#  ['bad',
#   'guys',
#   'mean',
#   'johnbrennan',
#   'barackobama',
#   'hillaryclinton',
#   'comey',
#   'aglynch',
#   'johnpodesta',
#   'dwstweets',
#   'joebiden',
#   'senfeinstein',
#   'speakerpelosi',
#   'senschumer',
#   'mean',
#   'donlemon',
#   'chriscuomo',
#   'ac360',
#   'theleadcnn',
#   'brookebcnn',
#   'asking',
#   'friend'],
#  ['doubt', 'rooted', 'political', 'machine'],
#  ['derangeddonald', 'keep', 'kissing', 'ass', 'popularity'],
#  ['touchy', 'feely'],
#  ['joe',
#   'biden',
#   'running',
#   'media',
#   'charlottesville',
#   'lie',
#   'trump',
#   '//washex',
#   'am/2gfi3ih',
#   'find',
#   'kind',
#   'fitting',
#   'joe',
#   'biden',
#   'thrown',
#   'hat',
#   'ring',
#   'based',
#   'lie',
#   'vp',
#   'lied',
#   'obumbler',
#   'years',
#   'people',
#   'like',
#   'doctor/plan',
#   'keep'],
#  ['chips', 'bought', 'fucking', 'delicious', 'thanks', 'suggestion'],
#  ['hes', 'even', 'pot'],
#  ['biden',
#   'saw',
#   'stumbled',
#   'apologies',
#   'tv',
#   'neck',
#   'lest',
#   '95',
#   'give',
#   'photoshoppers',
#   'credit',
#   'however'],
#  ['joebiden',
#   'intense',
#   'daily',
#   'viewer',
#   'global',
#   'politics',
#   'past',
#   'five',
#   'years',
#   '1st',
#   'fund',
#   'raiser',
#   'w/corp',
#   'entity',
#   'gave',
#   'others',
#   'ammunition',
#   'direct',
#   'quote',
#   'charlottesville',
#   'anti',
#   'semitic',
#   'replaced',
#   'super',
#   'powerful',
#   'statement',
#   'israeli',
#   'supporters',
#   'esp',
#   'aipac',
#   'better',
#   'move'],
#  ['former',
#   'vice',
#   'president',
#   'joebiden',
#   'said',
#   'raised',
#   'million',
#   '24',
#   'hours',
#   'announced',
#   'presidential',
#   'campaign',
#   '//trib',
#   'al/hsi8vmd'],
#  ['loose', 'much', 'fall', 'dictatorship'],
#  ['mean',
#   'illegal',
#   'absolutely',
#   'however',
#   'acting',
#   'like',
#   'weed',
#   'never',
#   'set',
#   'someone',
#   'path',
#   'return',
#   'acting',
#   'like',
#   'always',
#   'ruin',
#   'life'],
#  ['obsession',
#   'joe',
#   'biden',
#   'cringy',
#   'asf',
#   'com/liz',
#   'wheeler/status/1121901171285708800'],
#  ['creepyjoe',
#   'dives',
#   'deep',
#   'mine',
#   'son',
#   'death',
#   'positive',
#   'political',
#   'publicity',
#   'way',
#   'joebiden',
#   'could',
#   'defeat',
#   'realdonaldtrump',
#   'dnx',
#   'thedemocrats',
#   'wrongjoe',
#   'try',
#   'joekennedy',
#   'corybooker',
#   'com/ananavarro/status/1121810004464537607'],
#  ['laugh',
#   'learn',
#   'forget',
#   'joebiden',
#   'h/t',
#   'tommatzzie',
#   'com/carterbays/status/1121234165100421121'],
#  ['like',
#   'joebiden',
#   'watched',
#   'theview',
#   'bring',
#   'game',
#   'today',
#   'yes',
#   'looked',
#   'rusty',
#   'also',
#   'looked',
#   'old/tired',
#   'crisp',
#   'articulating',
#   'thoughts',
#   'understandably',
#   'hesitant',
#   'like',
#   'heart',
#   'message',
#   'hope',
#   'get',
#   'together'],
#  ['2020',
#   'battle',
#   'elizabeth',
#   'warren',
#   'accuses',
#   'joe',
#   'biden',
#   'siding',
#   'credit',
#   'card',
#   'companies',
#   'struggling',
#   'americans',
#   'http',
#   '//bit',
#   'ly/2dzny4p'],
#  ['joe', 'biden', 'meets', 'duck'],
#  ['joe',
#   'biden',
#   '//en',
#   'wikipedia',
#   'org/wiki/violent',
#   'crime',
#   'control',
#   'law',
#   'enforcement',
#   'act'],
#  ['made',
#   'arguments',
#   'spewed',
#   'ignorance',
#   'expect',
#   'people',
#   'take',
#   'seriously',
#   'six',
#   'years',
#   'twitter',
#   'managed',
#   'grand',
#   'total',
#   'two',
#   'tweets',
#   'aimed',
#   'joe',
#   'biden',
#   'responses',
#   'kremlin',
#   'talking',
#   'points',
#   'mute',
#   'time',
#   'troll',
#   'boy',
#   'bye'],
#  ['nope',
#   'believes',
#   'dregs',
#   'society',
#   'shown',
#   'time',
#   'time',
#   'zero',
#   'zilch',
#   'nada',
#   'self',
#   'reflection',
#   'dems',
#   'wrong',
#   'dems',
#   'good',
#   'conservatives',
#   'bad',
#   'delusion',
#   'grows'],
#  ['joe',
#   'biden',
#   'knows',
#   'better',
#   'anyone',
#   'smart',
#   'enough',
#   'lead',
#   'country',
#   'would',
#   'unable',
#   'keep',
#   'us',
#   'much',
#   'less',
#   'go',
#   'people',
#   'ass',
#   'kicked',
#   'many',
#   'many',
#   'times',
#   'dems',
#   'taxing',
#   'hell',
#   'wait'],
#  ['invading',
#   'personal',
#   'space',
#   'issue',
#   'know',
#   'better',
#   'better',
#   'maya',
#   'angelo'],
#  ['realdonaldtrump',
#   'joe',
#   'biden',
#   'better',
#   'looking',
#   'shape',
#   'commonsense',
#   'next',
#   'president',
#   'bye',
#   'felicia'],
#  ['hustled',
#   'plenty',
#   'money',
#   'countries',
#   'vp',
#   'use',
#   'money',
#   'stop',
#   'begging',
#   'americans'],
#  ['particular',
#   'person',
#   'many',
#   'voters',
#   'like',
#   '80s',
#   '08',
#   'election',
#   'either'],
#  ['finepeoplehoax',
#   'another',
#   'story',
#   'pushed',
#   'fakenewsmedia',
#   'enemyofthepeople'],
#  ['joebiden', 'man', 'empathetic', 'understand', 'theview', 'amjoyshow'],
#  ['go', 'home', 'joe', 'go', 'home'],
#  ['never'],
#  ['one', 'joebiden'],
#  ['donated',
#   'set',
#   'monthly',
#   'thanks',
#   'delivering',
#   'positive',
#   'message',
#   'country',
#   'needs',
#   'find',
#   'candidates',
#   'mudslinging',
#   'putting',
#   'berniesanders',
#   'runjoerun',
#   'votebluetosaveamerica'],
#  ['presidential',
#   'hopeful',
#   'sloppy',
#   'joe',
#   'biden',
#   'obama',
#   'white',
#   'house',
#   'one',
#   'scandal',
#   '17'],
#  ['yeah',
#   'fit',
#   'young',
#   'joe',
#   'biden',
#   'body',
#   'fit',
#   'young',
#   'guy',
#   'moron',
#   'like'],
#  ['joe',
#   'better',
#   'else',
#   'thoroughly',
#   'undermine',
#   'efforts',
#   'get',
#   'nomination',
#   'ijs'],
#  ['believe',
#   'ambition',
#   'cost',
#   'conscience',
#   'need',
#   'another',
#   'corporate',
#   'dem',
#   'saynottostatusquojoe'],
#  ['hold', 'breath'],
#  [],
#  ['poor', 'liberals', 'really', 'feel', 'sorry'],
#  ['mean',
#   'like',
#   'allowing',
#   'actually',
#   'present',
#   'case',
#   'heart',
#   'aches',
#   'day'],
#  ['sexual', 'harasser', 'racist', 'bigot', 'white', 'house'],
#  ['joe',
#   'biden',
#   'definition',
#   'establishment',
#   'politician',
#   'bernie',
#   'always',
#   'establishment',
#   'politicians',
#   'trump',
#   'also',
#   'ran',
#   'someone',
#   'establishment',
#   'hard',
#   'pass',
#   'joe'],
#  ['disagree', 'problems', 'result', 'dirty', 'money', 'politics'],
#  ['interesting',
#   'math',
#   'first',
#   '24',
#   'hours',
#   'joe',
#   'biden',
#   'campaign',
#   'raised',
#   'million',
#   '96',
#   '926',
#   'donors',
#   'average',
#   '65',
#   'per',
#   'donor',
#   'compare',
#   'bernie',
#   'sanders',
#   'first',
#   '24',
#   'hours',
#   'million',
#   '223',
#   '024',
#   'donors',
#   'average',
#   '27',
#   'bet',
#   'donors',
#   'young'],
#  ['healthfitnessrevolution',
#   'com/2016',
#   'presidential',
#   'hopefuls',
#   'fitness',
#   'reportcard/'],
#  ['hair', '30', 'years', 'ago', 'works'],
#  ['maya', 'would', 'correct'],
#  ['good',
#   'know',
#   'joe',
#   'biden',
#   'running',
#   'republican',
#   '2020',
#   'com/marijuanamoment/status/1121435168655458304'],
#  ['exactly',
#   'better',
#   'way',
#   'keep',
#   'fakenews',
#   'momentum',
#   'going',
#   'kudos',
#   'creepy',
#   'joe'],
#  ['joebiden',
#   'sir',
#   'honest',
#   '73',
#   'heard',
#   'words',
#   'charlottesville',
#   'potus',
#   'covered',
#   'bases',
#   'factions',
#   'causing',
#   'trouble',
#   'sides',
#   'career',
#   'politician',
#   'capable',
#   'fixing',
#   'soul',
#   'country'],
#  ['first', 'fundraiser', 'house', 'lobbyist', 'comcast', 'comcast'],
#  ['think',
#   'good',
#   'additional',
#   'voice',
#   'says',
#   'rep',
#   'jahimes',
#   'joe',
#   'biden',
#   'announcing',
#   'presidential',
#   'candidacy',
#   'know',
#   'right',
#   'guy',
#   'exactly',
#   'primary',
#   'process',
#   'himes',
#   'adds',
#   'america'],
#  ['elizabeth',
#   'warren',
#   'would',
#   'beloved',
#   'harvard',
#   'law',
#   'professor',
#   'presidential',
#   'candidate',
#   'barackobama',
#   'joebiden',
#   'worked',
#   'make',
#   'idea',
#   'form',
#   'consumer',
#   'financial',
#   'protection',
#   'bureau',
#   'law'],
#  ['seems',
#   'want',
#   'lose',
#   'vote',
#   'folks',
#   'supported',
#   'back',
#   'pretty',
#   'telling'],
#  ['gonna', 'residing', 'gitmo'],
#  ['hopped', 'plane', 'real', 'fundraiser', 'comcast', 'buddies'],
#  ['someone',
#   'tell',
#   'exactly',
#   'differentiates',
#   'joe',
#   'biden',
#   'guy',
#   'like',
#   'jeb',
#   'bush',
#   'mitt',
#   'romney'],
#  ['hatred',
#   'president',
#   'trump',
#   'running',
#   'dont',
#   'solid',
#   'policy',
#   'ideas',
#   'never',
#   'make',
#   '2020',
#   'primaries',
#   'president',
#   'trumps',
#   'economy',
#   'alone',
#   'beat',
#   'maga'],
#  ['myth',
#   'jews',
#   'replace',
#   'us',
#   'chanting',
#   'replace',
#   'us',
#   'bbc',
#   'com/news/av/world',
#   'asia',
#   '40911744/white',
#   'us',
#   'nationalists',
#   'chant',
#   'replace',
#   'us'],
#  ['stop', 'lying'],
#  ['doubt'],
#  ['satire',
#   'dog',
#   'whisperer',
#   'cesar',
#   'milan',
#   'breaks',
#   'joe',
#   'biden',
#   'sniffing',
#   'kissing',
#   'http',
#   '//infowars',
#   'com',
#   'powered',
#   'learn',
#   'stop',
#   'joe',
#   'biden',
#   'groping',
#   'sniffing',
#   'instructional',
#   'comedy',
#   'video',
#   'newswars',
#   'com/satire',
#   'dog',
#   'whisperer',
#   'cesar',
#   'milan',
#   'breaks',
#   'joe',
#   'biden',
#   'sniffing',
#   'kissing/'],
#  ['reflecting',
#   'back',
#   'nothing',
#   'ever',
#   'better',
#   'vote',
#   'much',
#   'money',
#   'candidate',
#   'take',
#   'lead',
#   'today',
#   'trusting',
#   'deals',
#   'washington',
#   'people',
#   'corporations',
#   'america',
#   'toxic',
#   'water',
#   'air',
#   'poor',
#   'trumpers',
#   'care',
#   'less'],
#  ['guessing',
#   'ur',
#   'absolutely',
#   'right',
#   'bet',
#   'joebiden',
#   'arrogantly',
#   'told',
#   'win',
#   'realdonaldtrump',
#   'fix',
#   'everything',
#   'president',
#   'desperation',
#   'lead',
#   'delusion',
#   'never',
#   'ends',
#   'well'],
#  ['nan'],
#  ['boooooooooooooooo',
#   'pauses',
#   'take',
#   'deep',
#   'breath',
#   'ooooooooooooooooooo'],
#  ['joe', 'biden'],
#  ['joe',
#   'biden',
#   'chief',
#   'nothing',
#   'man',
#   'policies',
#   'garbage',
#   'tier',
#   'especially',
#   '2019',
#   'com/bakkooonn/status/1121879586277433344'],
#  ['oh',
#   'bet',
#   'merkel',
#   'macron',
#   'trudeau',
#   'may',
#   'et',
#   'al',
#   'run',
#   'away',
#   'run',
#   'away'],
#  ['hey',
#   'grassroots',
#   'giver',
#   'fixed',
#   'income',
#   'call',
#   'joe',
#   'number',
#   'fan',
#   'go',
#   'joe'],
#  ['drop', 'support', 'andrewyang'],
#  ['joe',
#   'biden',
#   'cut',
#   'medicare',
#   'social',
#   'security',
#   '//youtu',
#   'be/wsdoblgfku0',
#   'via',
#   'youtube'],
#  ['politicslive',
#   'political',
#   'crimes',
#   'clearflynnnow',
#   'creepyunclejoe',
#   'joebiden',
#   'repmaxinewaters'],
#  ['stop',
#   'stop',
#   'sent',
#   'joebiden',
#   'contribution',
#   'several',
#   'candidates',
#   'like',
#   'gift',
#   'others',
#   'may',
#   'given',
#   'devalued',
#   'way',
#   'male',
#   'female',
#   'unattractive'],
#  ['joe',
#   'biden',
#   'essentially',
#   'running',
#   'meme',
#   'power',
#   'name',
#   'recognition',
#   'politics',
#   'terrible'],
#  ['thank',
#   'god',
#   'donald',
#   'trump',
#   'president',
#   'maga',
#   'trump2020',
#   'candaceowens2024'],
#  ['joebiden',
#   'right',
#   'whispers',
#   'actually',
#   'turning',
#   'full',
#   'blown',
#   'fog',
#   'horns',
#   'painiscoming'],
#  ['reverend'],
#  ['joebiden',
#   'wins',
#   'nomination',
#   'imagine',
#   'attack',
#   'ad',
#   '5pm',
#   'hell',
#   'breaks',
#   'loose',
#   'going',
#   'wake',
#   'president',
#   'sleepy',
#   'joe',
#   'asleep',
#   'switch',
#   'trump2020',
#   'maga',
#   'paid',
#   'assholes',
#   'elect',
#   'idiot'],
#  ['creepy', 'uncle', 'joe'],
#  ['get',
#   'plenty',
#   'money',
#   'corporate',
#   'fundraisers',
#   'big',
#   'pharma',
#   'side',
#   'know',
#   'represent',
#   'interests',
#   'american',
#   'people',
#   'terrible',
#   'track',
#   'record',
#   'giving',
#   'guy',
#   'fight',
#   'us',
#   'bernie2020'],
#  ['see', 'fake', 'joke'],
#  ['joe',
#   'biden',
#   'raises',
#   'million',
#   'topping',
#   'rivals',
#   'first',
#   'day',
#   'hauls',
#   'http',
#   '//cbdresource',
#   'blogspot',
#   'com/2019/04/joe',
#   'biden',
#   'raises',
#   '63',
#   'million',
#   'topping',
#   'html'],
#  ['poll',
#   'traitor',
#   'hillary',
#   'clinton',
#   'winning',
#   '2106',
#   'election',
#   'landslide'],
#  ['media',
#   'trope',
#   'portrays',
#   'lunch',
#   'bucket',
#   'joe',
#   'biden',
#   'regular',
#   'earth',
#   'guy',
#   'cares',
#   'deeply',
#   'regular',
#   'folks',
#   'pure',
#   'unadulterated',
#   'bullshit',
#   'counterpunch',
#   'org/2019/04/26/joe',
#   'biden',
#   'imperial',
#   'corporatist',
#   'wrapped',
#   'bloody',
#   'flag',
#   'charlottesville/'],
#  ['alyssa',
#   'milano',
#   'metoo',
#   'apologist',
#   'creepy',
#   'joe',
#   'biden',
#   'running',
#   'potus',
#   'com/alyssa',
#   'milano/status/1122227526443515905'],
#  ['stop', 'stealing', 'joebiden', 'phrases'],
#  ['look',
#   'tape',
#   'biden',
#   'acting',
#   'like',
#   'george',
#   'wallace',
#   'discussing',
#   'busing',
#   'integration'],
#  ['choices', 'right', 'would', 'class', 'integrity'],
#  ['must',
#   'assume',
#   'joe',
#   'biden',
#   'running',
#   'integrity',
#   'lie',
#   'scintilla',
#   'evidence',
#   'scandal',
#   'obama',
#   'amin',
#   'ought',
#   'get',
#   'landslide',
#   'victory',
#   'think'],
#  ['joebiden', 'demwit'],
#  ['stop',
#   'shipping',
#   'horses',
#   'slaughter',
#   'canada',
#   'mexico',
#   'good',
#   'ban',
#   'us',
#   'slaughterhouses',
#   'ever',
#   'opening',
#   'suppose',
#   'something',
#   'vp',
#   'never',
#   'happened'],
#  ['enough',
#   'american',
#   'people',
#   'money',
#   'spent',
#   'wrong',
#   'things',
#   'put',
#   'money',
#   'trump',
#   'man',
#   'done',
#   'country',
#   'president',
#   'man',
#   'supports',
#   'evil',
#   'harm',
#   'america'],
#  ['joebiden', 'thedemocrats'],
#  ['please', 'stop', 'absurd', 'campaign'],
#  ['joe',
#   'biden',
#   'first',
#   'fundraiser',
#   'rife',
#   'lobbyists',
#   'gop',
#   'donors',
#   '//theintercept',
#   'com/2019/04/25/joe',
#   'biden',
#   'presidential',
#   'bid',
#   'lobbyists',
#   'fundraiser/'],
#  ['hey',
#   'corey1911',
#   'thing',
#   'joebiden',
#   'racist',
#   'literally',
#   'want',
#   'part',
#   'society',
#   'kind',
#   'ally'],
#  ['joe',
#   'biden',
#   'finally',
#   'called',
#   'anita',
#   'hill',
#   'says',
#   'satisfied',
#   'apology',
#   'wants',
#   'change',
#   'stand',
#   'raf',
#   'dailykos',
#   'com/stories/2019/4/26/1853315/',
#   'joe',
#   'biden',
#   'finally',
#   'called',
#   'anita',
#   'hill',
#   'says',
#   'satisfied',
#   'apology',
#   'wants',
#   'change',
#   'detail',
#   'emaildkre'],
#  ['dem',
#   'candidates',
#   'taken',
#   'indivisible',
#   'pledge',
#   'make',
#   'primary',
#   'constructive',
#   'rally',
#   'behind',
#   'winner',
#   'work',
#   'beat',
#   'trump',
#   '//pledge',
#   'indivisible',
#   'org/',
#   'joebiden',
#   'berniesanders',
#   'kamalaharris',
#   'juliancastro',
#   'senwarren',
#   'petebuttigieg',
#   'jayinslee',
#   'retweet'],
#  ['joe',
#   'biden',
#   'fraud',
#   'plain',
#   'simple',
#   'truthdig',
#   'com/articles/joe',
#   'biden',
#   'phony',
#   'plain',
#   'simple/',
#   'xmtsxukpnuo',
#   'twitter'],
#  ['creepy',
#   'porn',
#   'lawyer',
#   'creepy',
#   'joe',
#   'biden',
#   'creeps',
#   'stick',
#   'together',
#   'com/nmmal',
#   'm/status/1122222206933721088'],
#  ['voting', 'joe', 'biden', 'candidate', 'like', 'voting', 'cuomo'],
#  ['joe',
#   'biden',
#   'imperial',
#   'corporatist',
#   'wrapped',
#   'bloody',
#   'flag',
#   'charlottesville',
#   'counterpunch',
#   'org/2019/04/26/joe',
#   'biden',
#   'imperial',
#   'corporatist',
#   'wrapped',
#   'bloody',
#   'flag',
#   'charlottesville/',
#   'fbclid',
#   'iwar1vrpgbgxevtgr',
#   'tys1fls',
#   'pzdhajvikma1tyldkl27mawevzlh3lqdss',
#   'natcounterpunch'],
#  ['joe',
#   'biden',
#   'really',
#   'showin',
#   'ass',
#   'election',
#   'com/jacobinmag/status/1121974279602569217'],
#  ['http',
#   '//time',
#   'com/5428669/saudi',
#   'arabia',
#   'military',
#   'relationship/',
#   'gop',
#   'joebiden',
#   'speakerpelosi'],
#  ['let',
#   'follow',
#   'joe',
#   'biden',
#   'ukrainian',
#   'connection',
#   'encourage',
#   'good',
#   'read',
#   'john',
#   'solomon',
#   'hill',
#   'article',
#   'talk',
#   'collusion',
#   'foreign',
#   'governments',
#   'influence',
#   'election'],
#  ['even', 'close', 'joe', 'always', 'advocate', 'women'],
#  ['ladies',
#   'theview',
#   'joebiden',
#   'lied',
#   'right',
#   'face',
#   'audience',
#   'believed',
#   'research',
#   'obama',
#   'scandals',
#   'benghazi',
#   'fastandfurious',
#   'bostonterrorist',
#   'apwiretappin',
#   'dreamact',
#   'sealdeaths',
#   'solyndra',
#   'many',
#   'dbongino',
#   'realjameswoods',
#   'donaldjtrumpjr',
#   'dloesch'],
#  ['think', 'enough', 'candidates'],
#  ['liberal',
#   'democrats',
#   'think',
#   'supposed',
#   'forget',
#   '40',
#   'years',
#   'destruction',
#   'vote',
#   'racist',
#   'candidate',
#   'joe',
#   'biden',
#   'wrote',
#   '94',
#   'crime',
#   'bill'],
#  ['joe',
#   'biden',
#   'president',
#   'http',
#   '//americablog',
#   'com/2019/04/joe',
#   'biden',
#   'president',
#   'html',
#   'via',
#   'americablog'],
#  ['joe',
#   'biden',
#   'aka',
#   'scratch',
#   'sniff/chester',
#   'molester',
#   'joke',
#   'trump',
#   'eat',
#   'spit',
#   'going',
#   'sniff',
#   'way',
#   'victory'],
#  ['calling',
#   'joe',
#   'biden',
#   'rapist',
#   'sooo',
#   'ked',
#   'assume',
#   'sanders',
#   'supporters'],
#  ['grope', 'change'],
#  ['nice',
#   'change',
#   'usually',
#   'reach',
#   'usually',
#   'feeling',
#   'prepubescent',
#   'teen',
#   'girls'],
#  ['women',
#   'politics',
#   'gay',
#   'straight',
#   'trans',
#   'poly',
#   'black',
#   'white',
#   'brown',
#   'purple',
#   'etc'],
#  ['would', 'want', 'go', 'backwards'],
#  ['interesting',
#   'foxnews',
#   'chose',
#   'dem',
#   'joelmartinrubin',
#   '2bring',
#   'charlottesville',
#   'like',
#   'joebiden',
#   'right',
#   'gate',
#   'organized',
#   'much',
#   'slander2lie',
#   'potus',
#   'said',
#   'demonstrating2',
#   'keep',
#   'historical',
#   'monuments',
#   'extremists',
#   'sides',
#   'soros',
#   'bused'],
#  ['old',
#   'joebiden',
#   'days',
#   'scandals',
#   'office',
#   'benghazi',
#   'fast',
#   'furious',
#   'irs',
#   'targeting',
#   'tea',
#   'party'],
#  ['call', 'still', 'manage', 'apologize'],
#  ['girl'],
#  ['nope'],
#  ['joebiden', 'democratic', 'best', 'republicans', 'eating', 'lunch'],
#  ['goon', 'thing', 'say', 'also', 'joe', 'biden', 'dogshit', 'candidate'],
#  ['condemnation',
#   'acts',
#   'white',
#   'nationalist',
#   'cry',
#   'distain',
#   'cry',
#   'hate',
#   'cry',
#   'better',
#   'nature',
#   'society',
#   'biden',
#   'campaign',
#   'announcement',
#   'rallying',
#   'excuse',
#   'good',
#   'sides'],
#  ['pledge',
#   'personally',
#   'sabotage',
#   'joe',
#   'biden',
#   'pete',
#   'buttigieg',
#   'campaigns',
#   'com/alyssa',
#   'milano/status/1122227526443515905'],
#  ['touch', 'establishment', 'talking', 'head'],
#  ['sadly', 'right'],
#  ['lmao', 'joke'],
#  ['alcohol',
#   'bigger',
#   'gateway',
#   'drug',
#   'alcohol',
#   'impairs',
#   'alcohol',
#   'lethal',
#   'addiction',
#   'yet',
#   'joe',
#   'biden',
#   'said',
#   'wants',
#   'lower',
#   'drinking',
#   'age'],
#  ['really', 'brainwashed', 'wow'],
#  ['youtube', 'com/watch', 'bffrqg69bu'],
#  ['discuss',
#   'plight',
#   'live',
#   'sadly',
#   'admittedly',
#   'schooled',
#   'enough',
#   'topic',
#   'discuss'],
#  ['biden',
#   'says',
#   'workers',
#   'candidate',
#   'worked',
#   'cut',
#   'medicare',
#   'social',
#   'security',
#   'timeshttp',
#   '//inthesetimes',
#   'com/article/21856/joe',
#   'biden',
#   'cut',
#   'medicare',
#   'social',
#   'security',
#   'retirement',
#   'age'],
#  ['dem',
#   'candidates',
#   'taken',
#   'indivisible',
#   'pledge',
#   'make',
#   'primary',
#   'constructive',
#   'rally',
#   'behind',
#   'winner',
#   'work',
#   'beat',
#   'trump',
#   '//pledge',
#   'indivisible',
#   'org/',
#   'joebiden',
#   'berniesanders',
#   'kamalaharris',
#   'juliancastro',
#   'senwarren',
#   'petebuttigieg',
#   'jayinslee',
#   'retweet'],
#  ['support', 'even', 'person', 'running'],
#  ['media',
#   'trope',
#   'portrays',
#   'lunch',
#   'bucket',
#   'joe',
#   'biden',
#   'regular',
#   'earth',
#   'guy',
#   'cares',
#   'deeply',
#   'regular',
#   'folks',
#   'pure',
#   'unadulterated',
#   'bullshit',
#   'real',
#   'constituents',
#   'wear',
#   'pinstripe',
#   'suits',
#   'works',
#   'wall',
#   'street',
#   'corporate',
#   'headquarters',
#   'counterpunch',
#   'org/2019/04/26/joe',
#   'biden',
#   'imperial',
#   'corporatist',
#   'wrapped',
#   'bloody',
#   'flag',
#   'charlottesville/',
#   'fbclid',
#   'iwar1vrpgbgxevtgr',
#   'tys1fls',
#   'pzdhajvikma1tyldkl27mawevzlh3lqdss'],
#  ['cgasparino',
#   'corrupt',
#   'deals',
#   'joe',
#   'biden',
#   'w/china',
#   'serious',
#   'directedly',
#   'harmed',
#   'us',
#   'interests',
#   'telecom',
#   'dealing',
#   'w/patent',
#   'issues',
#   'w/huawei',
#   'discovered',
#   'issues',
#   'would',
#   'make',
#   'unelectable',
#   'passed'],
#  ['worries', 'got', 'confused', 'joe', 'biden'],
#  ['youtube', 'com/watch', 'bffrqg69bu'],
#  ['figures'],
#  ['picture', 'joe', 'trying', 'pretend', 'one', 'see'],
#  ['boomer',
#   'biden',
#   'might',
#   'embrace',
#   'take',
#   'xer',
#   'obama',
#   'obama',
#   'respected',
#   'hillary',
#   'qualifications',
#   'appointed',
#   'secretary',
#   'state',
#   'disagreements',
#   'never',
#   'embraced',
#   'misogyny',
#   'obama',
#   'admires',
#   'warren',
#   'way'],
#  ['umm'],
#  ['umm'],
#  ['youtube', 'com/watch', 'bffrqg69bu'],
#  ['scrub',
#   'joebiden',
#   'ball',
#   'sack',
#   'since',
#   'enjoy',
#   'kissing',
#   'butt',
#   'holding',
#   'water',
#   'might',
#   'well',
#   'make',
#   'sure',
#   'creepyjoe',
#   'clean',
#   'tidy',
#   'fakenews'],
#  ['spoiler', 'alarm', 'tonight', 'endgame', 'thrones', 'kill', 'joe', 'biden'],
#  ['reality', 'hard', 'guess'],
#  ['fuckjoebiden',
#   'joebiden',
#   'biden2020',
#   'com/greg06897/status/1121863444251271168'],
#  ['joebiden'],
#  ['biden', 'terrible'],
#  ['want',
#   'judged',
#   'believed',
#   'decades',
#   'ago',
#   'rather',
#   'believe',
#   'rate',
#   'know',
#   'comfortable',
#   'know',
#   'great',
#   'weekend'],
#  ['creepy',
#   'joe',
#   'would',
#   'rather',
#   'spend',
#   'money',
#   'investigating',
#   'son'],
#  ['truth',
#   'universally',
#   'acknowledged',
#   'boldest',
#   'adversarial',
#   'journalism',
#   'treat',
#   'powerful',
#   'republican',
#   'hacks',
#   'way',
#   'joe',
#   'biden',
#   'would',
#   'treated',
#   '1991',
#   'com/anthropobscene/status/1122284413767835648'],
#  ['nan'],
#  ['talk', '3rd', 'person', 'much', 'smh'],
#  ['joe',
#   'biden',
#   'opposes',
#   'single',
#   'payer',
#   'healthcare',
#   'opposes',
#   'cannabis',
#   'legalization',
#   'supports',
#   'death',
#   'penalty',
#   'wrote',
#   '1994',
#   'crime',
#   'bill',
#   'voted',
#   'doma',
#   'voted',
#   'nafta',
#   'voted',
#   'iraq',
#   'war',
#   'voted',
#   'patriot',
#   'act',
#   'voted',
#   'repeal',
#   'glass',
#   'steagall',
#   'voted',
#   'make',
#   'harder',
#   'eliminate',
#   'student',
#   'debt'],
#  ['local',
#   'politicians',
#   'running',
#   'potus',
#   'would',
#   'expect',
#   'look',
#   'went',
#   'wrong',
#   'storms',
#   'contribution',
#   'disastrous',
#   'response',
#   'said',
#   'born',
#   'parents',
#   'raised',
#   'one'],
#  ['impeach', 'trump', 'joe', 'biden', 'president'],
#  ['oh',
#   'joe',
#   'loved',
#   'advertisement',
#   'made',
#   'youtube',
#   'com/watch',
#   'bffrqg69bu'],
#  ['probably',
#   'air',
#   'twitter',
#   'follow',
#   'potus',
#   'joe',
#   'biden',
#   'dem',
#   '2020',
#   'get',
#   'attendance',
#   'home',
#   'state',
#   'thank',
#   'djt',
#   'fulfilling',
#   'promise',
#   'usa',
#   'com/kayleighmcenany/status/1122279118731644929'],
#  ['joe',
#   'biden',
#   '1974',
#   'ready',
#   'prostitute',
#   'wealthy',
#   'donors',
#   'com/ibrahimas97/status/1121925027123924993/video/1'],
#  ['appointed',
#   'position',
#   'confirmed',
#   'dems',
#   'held',
#   'majority',
#   'senate',
#   'leave',
#   '2017',
#   'say',
#   'would',
#   'true',
#   'warren'],
#  ['yes', 'everyone', 'lies', 'except', 'trumplethinskin', 'get', 'real'],
#  ['must', 'way', 'smiling', 'nobody', 'else', 'would', 'want'],
#  ['trump'],
#  ['fuck',
#   'joe',
#   'joebiden',
#   'strange',
#   'change',
#   'purse',
#   'com/wandaiswhite/status/1121862198995800073'],
#  ['check',
#   'realtimblack',
#   'tweet',
#   'com/realtimblack/status/1122221691936169985',
#   '09'],
#  ['check',
#   'joebiden',
#   'alziemers',
#   'remember',
#   'scandals',
#   '18',
#   'major',
#   'scandals',
#   'obama',
#   '/biden',
#   'scandal',
#   'free',
#   'presidency',
#   'breitbartttp',
#   '//bit',
#   'ly/2chqfgr',
#   'via',
#   'breitbartnews',
#   'com/dailycaller/status/1122081706931105794'],
#  ['sign', 'great', 'graphics'],
#  ['give',
#   'dime',
#   'thanks',
#   'running',
#   'gonna',
#   'great',
#   'show',
#   'democrats',
#   'start',
#   'turning'],
#  ['love', 'reply', 'come', 'better', 'one'],
#  ['oh',
#   'guaranteeing',
#   'jen',
#   'gonna',
#   'make',
#   'winning',
#   'tweets',
#   'primary',
#   'election'],
#  ['joe',
#   'biden',
#   'asserts',
#   'thomas',
#   'hearings',
#   'trying',
#   'work',
#   'within',
#   'rules',
#   'chairman',
#   'judiciary',
#   'committee',
#   'set',
#   'rules',
#   'particular',
#   'allowing',
#   'people',
#   'could',
#   'supported',
#   'anita',
#   'hill',
#   'testimony',
#   'testify'],
#  ['sister',
#   'arabic',
#   'linguist',
#   'agency',
#   'shall',
#   'remain',
#   'nameless',
#   'iraq',
#   'wars',
#   'still',
#   'harbors',
#   'intense',
#   'personal',
#   'animus',
#   'george',
#   'bush',
#   'rejected',
#   'work'],
#  ['nan'],
#  ['great',
#   'photo',
#   'abby',
#   'look',
#   'pretty',
#   'glad',
#   'guys',
#   'go',
#   'light',
#   'arena',
#   'demands',
#   'tough',
#   'questions',
#   'answered'],
#  ['nafta',
#   'iraq',
#   'war',
#   'patriot',
#   'act',
#   'welfare',
#   'reform',
#   'wall',
#   'street',
#   'bailout',
#   'bankruptcy',
#   'reform',
#   'defense',
#   'marriage',
#   'telecom',
#   'act',
#   '1996',
#   'repeal',
#   'glass',
#   'steagall',
#   'normalizing',
#   'trade',
#   'w/',
#   'china',
#   'issue',
# ...
#  ['well',
#   'joe',
#   'biden',
#   'talk',
#   'trump',
#   'anymore',
#   'biden',
#   'pressured',
#   'china',
#   'giving',
#   'son',
#   'billion',
#   'china',
#   '1st',
#   'oh',
#   'joe',
#   'done',
#   'believe',
#   'goggle',
#   'internet',
#   'nerve',
#   'talk',
#   'trump',
#   'act',
#   'like',
#   'honest'],
#  ['hell', 'creeper', 'joe'],
#  ['joe',
#   'biden',
#   'interview',
#   'eric',
#   'andre',
#   'show',
#   'exactly',
#   'voting',
#   '2020',
#   '//youtu',
#   'be/0bxi01iiwmw',
#   'joe2020',
#   'joebiden',
#   'barackobama',
#   'democracy',
#   'dnc',
#   'democrats'],
#  ['joe',
#   'biden',
#   'talked',
#   'seated',
#   'crowds',
#   'ia',
#   'told',
#   'policy',
#   'details',
#   'like',
#   'know',
#   'current',
#   'position',
#   'hyde',
#   'amendment'],
#  ['fo', 'mean', 'anything'],
#  ['every', 'country', 'goal', 'world', 'biggest', 'superpower'],
#  ['boooo'],
#  ['never', 'vote', 'veneered', 'hair', 'plugged', 'republican'],
#  ['joebiden', 'keep', 'calling', 'president', 'trump', 'realdonaldtrump'],
#  ['job', 'work', 'honors', 'oh', 'yes', 'josefina'],
#  ['perfect',
#   'vp',
#   'candidate',
#   'pair',
#   'joebiden',
#   'com/bakari',
#   'sellers/status/1123660750361382913'],
#  ['forget',
#   'ticket',
#   'joe',
#   'biden/',
#   'kamala',
#   'harris',
#   'vp',
#   'sally',
#   'yates',
#   'attorney',
#   'general'],
#  ['would', '5bucks', 'wasted', 'would', 'never', 'vote', 'apes', 'shadow'],
#  ['winning', 'ticket', 'joe', 'biden', 'kamala', 'kamalaharris', 'joebiden'],
#  ['imagine',
#   'joebiden',
#   'surprise',
#   'berniesanders',
#   'beats',
#   'iowa',
#   'new',
#   'hampshire',
#   'corporate',
#   'money',
#   'gonna',
#   'dry',
#   'quick',
#   'gohomejoeyouredrunk',
#   '2008alloveragain'],
#  ['joe', 'biden', 'sr', 'apple', 'fall', 'far', 'tree'],
#  ['wow',
#   'sexist',
#   'much',
#   'woman',
#   'need',
#   'running',
#   'mate',
#   'man',
#   'running',
#   'mate',
#   'woman',
#   'benthe',
#   'candidate',
#   'sexist'],
#  ['joe',
#   'plus',
#   'biden',
#   'plus',
#   'takes',
#   'plus',
#   'plus',
#   'lead',
#   'http',
#   'billoreilly',
#   'com/b/joe',
#   'biden',
#   'takes',
#   'lead/',
#   '609524972259153562',
#   'html',
#   'utm',
#   'medium',
#   'email',
#   'utm',
#   'campaign',
#   'mod',
#   'utm',
#   'source',
#   'newsletter',
#   'xmoyoknxrqa',
#   'twitter'],
#  ['com/ajitxsingh/status/1123566079790338048', '21'],
#  ['sad', 'joebiden', 'loosing'],
#  ['hahahahaha', 'troll', 'realist'],
#  ['kamala',
#   'harris',
#   'could',
#   'get',
#   'desperately',
#   'needed',
#   'traction',
#   'really',
#   'digging',
#   'biden',
#   'record',
#   'demonstrating',
#   'policy',
#   'orientation',
#   'flatly',
#   'anti',
#   'worker'],
#  ['uck', 'touches', 'child', 'like'],
#  ['doesnt',
#   'make',
#   'th',
#   'point',
#   'joebiden',
#   'achieves',
#   'nothing',
#   '40',
#   'years',
#   'except',
#   'bad',
#   'judgment',
#   'egregious',
#   'errors',
#   'anita',
#   'hill',
#   'mass',
#   'incarceration',
#   'prison',
#   'industrial',
#   'complex',
#   'glass',
#   'steagall',
#   'bank',
#   'bill',
#   'mbna',
#   'voting',
#   'invade',
#   'iraq',
#   'makes',
#   'big',
#   'deal',
#   'th',
#   'troops'],
#  ['give', 'fruitcake'],
#  ['realdonaldtrump',
#   'sure',
#   'concerned',
#   'joebiden',
#   'look',
#   'like',
#   'spoiled',
#   'brat',
#   'playing',
#   'school',
#   'boy',
#   'threats',
#   'criticism',
#   'immature',
#   'insults',
#   'hear',
#   'steps'],
#  ['joebiden',
#   'talked',
#   'little',
#   'else',
#   'got',
#   'campaign',
#   'president',
#   'sounds',
#   'like',
#   'might',
#   'little',
#   'scared',
#   'probably',
#   'scared',
#   'bernie',
#   'elizabeth',
#   'others',
#   'going',
#   'take'],
#  ['many',
#   'times',
#   'erinburnett',
#   'going',
#   'repeat',
#   'trump',
#   'inflamatory',
#   'rhetoric',
#   'joe',
#   'biden',
#   'unfortunately',
#   'heard',
#   'first',
#   'time',
#   'stop',
#   'bull',
#   'horn',
#   'trump',
#   'cnnpolitics'],
#  ['joe',
#   'biden',
#   'get',
#   'american',
#   'people',
#   'want',
#   'government',
#   'interfering',
#   'another',
#   'country',
#   'civil',
#   'war',
#   'besides',
#   'know',
#   'oil',
#   'biden',
#   'could',
#   'vote',
#   'iraq',
#   'war',
#   'know',
#   'knows',
#   'today',
#   'com/joebiden/status/1123352740363681792'],
#  ['looks',
#   'like',
#   'joebiden',
#   'dirt',
#   'hands',
#   'son',
#   'com/kamvtv/status/1123725537346760704'],
#  ['com/ajitxsingh/status/1123566079790338048', '21'],
#  ['another',
#   'example',
#   'elites',
#   'using',
#   'identity',
#   'politics',
#   'weaponized',
#   'goals',
#   'never',
#   'principles',
#   'women',
#   'matter'],
#  ['joe',
#   'biden',
#   'past',
#   '24',
#   'hours',
#   'could',
#   'gone',
#   'perfectly',
#   'cnnpolitics',
#   'cnn',
#   'com/2019/04/30/politics/joe',
#   'biden',
#   'donald',
#   'trump',
#   'cnn',
#   'poll/index',
#   'html'],
#  ['revise', 'targeting', 'algorithms', 'top', 'democrat'],
#  ['kidding', 'right', 'joechina', 'must', 'triggering', 'memories'],
#  ['realdonaldtrump',
#   'hell',
#   'obsession',
#   'joe',
#   'biden',
#   'better',
#   'man',
#   'qualified',
#   'man',
#   'ever',
#   'entire',
#   'country',
#   'base',
#   'impeachtrump'],
#  ['fire',
#   'remove',
#   'barr',
#   'w/',
#   'prison',
#   'asap',
#   'gavinnewsom',
#   'johnbrennan',
#   'repjoekennedy',
#   'ronwyden',
#   'senatortomudall',
#   'repdebhaaland',
#   'senatorleahy',
#   'senmarkey',
#   'repbarragan',
#   'ilhanmn',
#   'aoc',
#   'senjeffmerkley',
#   'repswalwell',
#   'massago',
#   'chriscoons',
#   'colinallredtx',
#   'joebiden',
#   'barackobama'],
#  ['still',
#   'looking',
#   'daddy',
#   'approval',
#   'love',
#   'silly',
#   'nickname',
#   'joe',
#   'biden',
#   'think',
#   'one'],
#  ['heaven', 'forbid', 'cange', 'conversation', 'tone', 'worried'],
#  ['joebiden',
#   '//m',
#   'facebook',
#   'com/story',
#   'php',
#   'story',
#   'fbid',
#   '1374533616029405',
#   'id',
#   '739440422872064',
#   'sfnsn',
#   'mo',
#   'anybody',
#   'vote',
#   'lying',
#   'ass'],
#  ['old', 'let', 'find', 'somebody', 'else'],
#  ['cahoots'],
#  ['let', 'talk', 'sister', 'trademarks', 'china'],
#  ['joe',
#   'biden',
#   'tells',
#   'year',
#   'old',
#   'girl',
#   'getting',
#   'old',
#   '//go',
#   'shr',
#   'lc/2v9rzy0',
#   'prisonplanet',
#   'aprillajune'],
#  ['nicholsuprising',
#   'mitchellreports',
#   'lawrence',
#   'michaelsteele',
#   'maddow',
#   'morrningjoe',
#   'biden',
#   'joe',
#   'biden',
#   'asked',
#   'today',
#   'trump',
#   'tweeting',
#   'good',
#   'question',
#   'maybe',
#   'trump',
#   'think',
#   'builds',
#   'take',
#   'need',
#   'change',
#   'big',
#   'change',
#   'joe',
#   'time',
#   'past'],
#  ['whatever',
#   'stay',
#   'away',
#   'joe',
#   'biden',
#   'especially',
#   'asks',
#   'running',
#   'mate'],
#  ['love', 'trump', 'family', 'people'],
#  ['happened',
#   'soul',
#   'america',
#   'derangeddonald',
#   'administration',
#   'us',
#   'united',
#   'states',
#   'america',
#   'remember',
#   'togetherwewill',
#   'biden2020',
#   'joebiden',
#   'imridinwithbiden',
#   'cnn',
#   'com/2019/05/01/health/amputee',
#   'airline',
#   'batteries',
#   'confiscated',
#   'trnd/index',
#   'html'],
#  ['next', 'gun', 'range', 'school', 'practice', 'lunch', 'break'],
#  ['old', 'looks', 'sickly'],
#  ['joebiden',
#   'yet',
#   'stealing',
#   'someone',
#   'elses',
#   'ideas',
#   'make',
#   'america',
#   'moral',
#   'really',
#   'lecturing',
#   'others',
#   'dignity',
#   'morality',
#   'hes',
#   'kidding',
#   'right',
#   'dems',
#   'even',
#   'know',
#   'morality',
#   'dignity',
#   'mean',
#   'seems',
#   'like',
#   'pattern',
#   'misapplying',
#   'terms',
#   'projecting'],
#  ['joe', 'biden', 'really', 'trash', 'huh'],
#  ['hillaryclinton',
#   'barackobama',
#   'joebiden',
#   'comey',
#   'rest',
#   'knew',
#   'biggest',
#   'scandal',
#   'american',
#   'history',
#   'obamagate'],
#  ['people',
#   'replying',
#   'tweet',
#   'future',
#   'baseball',
#   'game',
#   'shooters',
#   'real',
#   'indictment',
#   'train',
#   'starts',
#   'illegal',
#   'spying',
#   'heads',
#   'explode'],
#  ['rest',
#   'assured',
#   'joe',
#   'biden',
#   'take',
#   'fight',
#   'trump',
#   'literally',
#   'republican',
#   'problem',
#   'political',
#   'system',
#   'nytimes',
#   'com/2019/01/23/us/politics/biden',
#   'speech',
#   'fred',
#   'upton',
#   'amp',
#   'html'],
#  ['somehow',
#   'potus',
#   'thinks',
#   'unions',
#   'going',
#   'go',
#   'w/',
#   'joebiden',
#   'kidding',
#   'trump',
#   'never',
#   'pays',
#   'workers',
#   'vote',
#   'unfitforoffice',
#   'impeachdonadtrump',
#   'com/crewcrew/status/1124071212525682688'],
#  ['give', 'money', 'trump', 'campaign', 'keep', 'america', 'great'],
#  [],
#  ['yes',
#   'stupid',
#   'could',
#   'name',
#   'like',
#   'shady',
#   'boots',
#   'things',
#   'cheney',
#   'done',
#   'well',
#   'sixth',
#   'one',
#   'shot',
#   'friend',
#   'face'],
#  ['least',
#   'uncle',
#   'joe',
#   'clear',
#   'conscience',
#   'goes',
#   'bed',
#   'night',
#   'demons',
#   'head',
#   'mr',
#   'graham',
#   'shread',
#   'integrity',
#   'buried',
#   'senjohnmccain'],
#  ['un',
#   'centavo',
#   'partido',
#   'en',
#   'dos',
#   'ni',
#   'el',
#   'sander',
#   'el',
#   'miyonarip',
#   'ni',
#   'el',
#   'otro',
#   'que',
#   'aprendio',
#   'espa',
#   'ol',
#   'para',
#   'hasernos',
#   'el',
#   'cuento',
#   'de',
#   'la',
#   'buena',
#   'pipa'],
#  ['campaign',
#   'joe',
#   'none',
#   'give',
#   'damn',
#   'people',
#   'us',
#   'support',
#   'donald',
#   'trump',
#   'interested',
#   'rule',
#   'law',
#   'seek',
#   'special',
#   'treatment',
#   'favors',
#   'need'],
#  ['done',
#   'say',
#   'ukraine',
#   'hillary',
#   'obama',
#   'rice',
#   'lynch',
#   'brennan',
#   'clapper',
#   'mccabe',
#   'fisa',
#   'deep',
#   'rest',
#   'except',
#   'extorted',
#   'bribed',
#   'threatened',
#   'ukraine',
#   'wow',
#   'creepy',
#   'joe',
#   'evil',
#   'side'],
#  ['still', 'prefer', 'biden', 'sanders'],
#  ['china', 'continue', 'help'],
#  ['serving',
#   'vp',
#   'allowed',
#   'cover',
#   'son',
#   'ukraine',
#   'wanted',
#   'give',
#   'nukes',
#   'nation',
#   'screams',
#   'death',
#   'america',
#   'think',
#   'china',
#   'threat',
#   'remind',
#   'us',
#   'really',
#   'working'],
#  ['correct', 'responsible'],
#  ['lindsaygraham', 'trying', 'mimic', 'trump', 'bullying', 'style', 'sad'],
#  ['dude', 'make', 'sentence'],
#  ['fake',
#   'french',
#   'accent',
#   'sssank',
#   'heavennnnn',
#   'inhale',
#   'foar',
#   'leetell',
#   'girrrrllssss'],
#  ['agree',
#   'joe',
#   'biden',
#   'walking',
#   'trumps',
#   'head',
#   'lol',
#   'threat',
#   'trump',
#   'knows',
#   'bully',
#   'joebiden2020',
#   'elizabeth',
#   'warren',
#   'go',
#   'get',
#   'another',
#   'beer',
#   'lol',
#   'com/kwikwarren/status/1124077803882864641'],
#  ['everything'],
#  ['sad',
#   'say',
#   'think',
#   'got',
#   'pedophilia',
#   'imagine',
#   'amount',
#   'money',
#   'power',
#   'would',
#   'worth',
#   'selling',
#   'like',
#   'got',
#   'absolutely',
#   'terrified',
#   'desperate',
#   'totally',
#   'reckless',
#   'behave',
#   'like'],
#  ['2015',
#   'clip',
#   'joe',
#   'biden',
#   'calling',
#   'dick',
#   'cheney',
#   'decent',
#   'man',
#   'resurfaces',
#   'sparking',
#   'backlash',
#   'com/i/moments/1124060408371982345'],
#  ['progressives',
#   'cannot',
#   'happy',
#   'force',
#   'fed',
#   'told',
#   'fall',
#   'line',
#   'voting',
#   'joe',
#   'biden',
#   'old',
#   'white',
#   'man',
#   'dems',
#   'would',
#   'say',
#   'correct',
#   'second',
#   'choice',
#   'least',
#   'polls',
#   'another',
#   'old',
#   'white',
#   'man'],
#  ['using',
#   'middle',
#   'class',
#   'insult',
#   'never',
#   'mean',
#   'never',
#   'say',
#   'anything',
#   'liberal',
#   'elite'],
#  ['newsone',
#   'colorofchange',
#   'demgovs',
#   'kylegriffin1',
#   'nnpa',
#   'blackpress',
#   'uft',
#   'thedemocrats',
#   'revdrbarber',
#   'capable',
#   'continuing',
#   'play',
#   'republican',
#   'nixon',
#   'southern',
#   'strategy',
#   'power',
#   'votes',
#   'installing',
#   'judges',
#   'undoing',
#   'assimilating',
#   'accommodating',
#   'integrated',
#   'public',
#   'education'],
#  ['thanks', 'joe', 'biden', 'putting', 'stab', 'establishment'],
#  ['sound', 'like', 'chicoms', 'creepy', 'joe', 'biden'],
#  ['hoco',
#   'joebiden',
#   'support',
#   'joe',
#   'every',
#   'corner',
#   'state',
#   'joe2020',
#   'com/herbjsmith/status/1124080633284845574'],
#  ['surprise', 'joe', 'biden', 'watching', 'last', '40', 'years'],
#  ['said',
#   'disgusts',
#   'democrat',
#   'would',
#   'ever',
#   'speak',
#   'cheney',
#   'positive',
#   'light',
#   'biden',
#   'even',
#   'figure',
#   'choices',
#   'unfortunately'],
#  ['really',
#   'helpful',
#   'right',
#   'trump',
#   'currently',
#   'scared',
#   'biden',
#   'posts',
#   'like',
#   'puts',
#   'ammunition',
#   'wrong',
#   'hands'],
#  ['trump', '2020'],
#  ['oh', 'sweetie', 'bless', 'two', 'sided', 'heart'],
#  ['poundsand'],
#  ['probably',
#   'video',
#   'photo',
#   'eyes',
#   'closed',
#   'people',
#   'put',
#   'mendacity'],
#  ['joebiden', 'wow', 'idea', 'china', 'bought', 'son', 'got', 'deal'],
#  ['absolutely', 'pathetic'],
#  ['noooooooooooooooooooooooooooo'],
#  ['acosta', 'complain', 'dangerous', 'suppression', '1st', 'amendment'],
#  ['omg', 'billion', 'dollar', 'deal', 'wth', 'lock'],
#  ['joebiden', 'got', 'go', 'away', 'com/sanasaeed/status/1124017753692737536'],
#  ['trump',
#   '13',
#   'biggest',
#   'business',
#   'failures',
#   'rolling',
#   'stone',
#   'rollingstone',
#   'com/politics/politics',
#   'news/donald',
#   'trumps',
#   '13',
#   'biggest',
#   'business',
#   'failures',
#   '59556/',
#   'utm',
#   'medium',
#   'social',
#   'utm',
#   'source',
#   'twitter',
#   'utm',
#   'campaign',
#   'social',
#   'bar',
#   'utm',
#   'content',
#   'bottom',
#   'amp',
#   'utm',
#   'id',
#   '59556'],
#  ['wrong', 'middle', 'class', 'wiper', 'people', 'bottoms'],
#  ['middle', 'class', 'class'],
#  ['joebiden',
#   'loser',
#   'cannot',
#   'answer',
#   'questions',
#   'unless',
#   'prepped',
#   'cnn',
#   'buddies',
#   'idiotinchief',
#   'title',
#   'biden',
#   'win',
#   'com/marcusdipaola/status/1123762758795825155'],
#  ['hell',
#   'yeah',
#   'biden',
#   'called',
#   'barr',
#   'resign',
#   'apparently',
#   'creepy',
#   'uncle',
#   'joe',
#   'like',
#   'people',
#   'breathe',
#   'neck'],
#  ['political',
#   'wisdom',
#   'joe',
#   'biden',
#   'many',
#   'see',
#   'statement',
#   'dick',
#   'cheney',
#   'shows',
#   'willingness',
#   'work',
#   'people',
#   'across',
#   'aisle',
#   'passing',
#   'policy',
#   'numbers',
#   'game'],
#  ['perjured',
#   'multiple',
#   'times',
#   'collusion',
#   'unambiguous',
#   'lie',
#   'report',
#   'goes',
#   'way',
#   'say',
#   'looked',
#   'conspiracy',
#   'collusion',
#   'even',
#   'narrowed',
#   'pre',
#   'arranged',
#   'agreement',
#   'hack'],
#  ['joe',
#   'biden',
#   'video',
#   'literally',
#   'bragging',
#   'blackmailed',
#   'ukrainian',
#   'government',
#   'firing',
#   'prosecutor',
#   'hijacking',
#   '1bil',
#   'us',
#   'guaranteed',
#   'loans',
#   'already',
#   'approved',
#   'obama',
#   'admin',
#   'ukraine',
#   'faced',
#   'russian',
#   'incursion',
#   '//youtu',
#   'be/rto1oigwfvs'],
#  ['see',
#   'difference',
#   'realdonaldtrump',
#   'joebiden',
#   'terms',
#   'policy',
#   'shit',
#   'stains',
#   'care',
#   'donors',
#   'voters',
#   'say',
#   'whatever',
#   'bullshit',
#   'win',
#   'dnc',
#   'dccc',
#   'election',
#   'primary'],
#  ['lindsey', 'still', 'yaking', 'away', 'becoming', 'annoying'],
#  ['mob', 'mean', 'joe', 'joined', 'trump', 'crime', 'family'],
#  ['got', 'long', 'road', 'ahead', 'us', 'important', 'watch', 'listen'],
#  ['missed', 'gotcha', 'good', 'idea'],
#  ['dumbest', 'thing', 'said', 'yet'],
#  ['know', 'sad', 'miss', 'lindsey', 'traitorous', 'behavior'],
#  ['really',
#   'expect',
#   'anyone',
#   'take',
#   'seriously',
#   'tweets',
#   'like',
#   'sad',
#   'btw',
#   'middle',
#   'class',
#   'probably',
#   'appreciate',
#   'dissed',
#   'better',
#   'hope',
#   'many',
#   'among',
#   'constituents',
#   'appreciate',
#   'put'],
#  ['middle',
#   'class',
#   'joe',
#   'nice',
#   'american',
#   'ring',
#   'much',
#   'better',
#   'moscow'],
#  ['mom', 'ukranian', 'corruption', 'scandel', '2016', 'get'],
#  ['recently', 'bad', 'plugs', 'til', '2016', 'allow', 'thats'],
#  ['joe',
#   'biden',
#   'visited',
#   'view',
#   'talk',
#   'touching',
#   'anita',
#   'hill',
#   'subsonic',
#   'air',
#   'travel',
#   '//slate',
#   'com/news',
#   'politics/2019/04/joe',
#   'biden',
#   'view',
#   'interview',
#   'anita',
#   'hill',
#   'html',
#   'via',
#   'slate'],
#  ['know', 'video', '2015'],
#  ['uhmmm',
#   'joebiden',
#   'hope',
#   'dont',
#   'mean',
#   'com/emmavigeland/status/1123975598999789571'],
#  ['read',
#   'transcript',
#   'widdle',
#   'windsey',
#   'trying',
#   'like',
#   'poppa',
#   'tweeting',
#   'falsehoods',
#   'maryland',
#   'democrat',
#   'asked',
#   'barr',
#   'bob',
#   'mueller',
#   'support',
#   'conclusion',
#   'know',
#   'whether',
#   'bob',
#   'mueller',
#   'supported',
#   'conclusion',
#   'knowing',
#   'got',
#   'mueller',
#   'memo',
#   'disagreeing',
#   'liarincheif'],
#  ['feeling', 'joe', 'ooops', 'pun', 'intended', 'well', 'maybe'],
#  ['leslie', 'knope', 'would', 'disappointed', 'joe', 'biden'],
#  ['hahaha'],
#  ['middle', 'class', 'better', 'low', 'class', 'trash', 'graham'],
#  ...]

# %%
phrases = Phrases(sent, min_count=30, progress_per=10000)
phrases

# %%
bigram = Phraser(phrases)

# %%
sentences = bigram[sent]
sentences

# %%
#sanity check
word_freq = defaultdict(int)
for sent in sentences:
    for i in sent:
        word_freq[i] += 1
len(word_freq)
# Out:
# 47709

# %%
sorted(word_freq, key=word_freq.get, reverse=True)[:20]
# Out:
# ['joe_biden',
#  'joebiden',
#  'trump',
#  'biden',
#  'joe',
#  'like',
#  'president',
#  'people',
#  'get',
#  'would',
#  'one',
#  'know',
#  'think',
#  'vote',
#  'obama',
#  'us',
#  'need',
#  'want',
#  'going',
#  'ukraine']

# %%
cores = multiprocessing.cpu_count() # Count the number of cores in a computer

# %%
 = Word2Vec(min_count=3,
                     window=4,
                     size=300,
                     sample=1e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20,
                     workers=cores-1)

# %%
t = time()

w2v_model.build_vocab(sentences, progress_per=10000)

print('Time to build vocab: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to build vocab: 0.12 mins

# %%
t = time()

w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=30, report_delay=1)

print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to train the model: 120.52 mins

# %%
#makes the model memory efficient
w2v_model.init_sims(replace=True)

# %%
#exploring the model
w2v_model.wv.most_similar(positive=["biden"]) #checks most similar words related to biden
# Out:
# [('son', 0.9734784960746765),
#  ('joe_biden', 0.9700943231582642),
#  ('company', 0.9657618403434753),
#  ('board', 0.9641777276992798),
#  ('hunter', 0.962968647480011),
#  ('worked', 0.9602497816085815),
#  ('vice_president', 0.9601132273674011),
#  ('claims', 0.9596114158630371),
#  ('campaign', 0.95936119556427),
#  ('corruption', 0.9580628871917725)]

# %%
w2v_model.wv.most_similar(positive=["biden"])
# Out:
# [('son', 0.9734784960746765),
#  ('joe_biden', 0.9700943231582642),
#  ('company', 0.9657618403434753),
#  ('board', 0.9641777276992798),
#  ('hunter', 0.962968647480011),
#  ('worked', 0.9602497816085815),
#  ('vice_president', 0.9601132273674011),
#  ('claims', 0.9596114158630371),
#  ('campaign', 0.95936119556427),
#  ('corruption', 0.9580628871917725)]

# %%
def tsnescatterplot(model, word, list_names):
    """ Plot in seaborn the results from the t-SNE dimensionality reduction algorithm of the vectors of a query word,
    its list of most similar words, and a list of words.
    """
    arrays = np.empty((0, 300), dtype='f')
    word_labels = [word]
    color_list  = ['red']

    # adds the vector of the query word
    arrays = np.append(arrays, model.wv.__getitem__([word]), axis=0)
    
    # gets list of most similar words
    close_words = model.wv.most_similar([word])
    
    # adds the vector for each of the closest words to the array
    for wrd_score in close_words:
        wrd_vector = model.wv.__getitem__([wrd_score[0]])
        word_labels.append(wrd_score[0])
        color_list.append('blue')
        arrays = np.append(arrays, wrd_vector, axis=0)
    
    # adds the vector for each of the words from list_names to the array
    for wrd in list_names:
        wrd_vector = model.wv.__getitem__([wrd])
        word_labels.append(wrd)
        color_list.append('green')
        arrays = np.append(arrays, wrd_vector, axis=0)
        
    # Reduces the dimensionality from 300 to 50 dimensions with PCA
    reduc = PCA(n_components=21).fit_transform(arrays)
    
    # Finds t-SNE coordinates for 2 dimensions
    np.set_printoptions(suppress=True)
    
    Y = TSNE(n_components=2, random_state=0, perplexity=15).fit_transform(reduc)
    
    # Sets everything up to plot
    df = pd.DataFrame({'x': [x for x in Y[:, 0]],
                       'y': [y for y in Y[:, 1]],
                       'words': word_labels,
                       'color': color_list})
    
    fig, _ = plt.subplots()
    fig.set_size_inches(9, 9)
    
    # Basic plot
    p1 = sns.regplot(data=df,
                     x="x",
                     y="y",
                     fit_reg=False,
                     marker="o",
                     scatter_kws={'s': 40,
                                  'facecolors': df['color']
                                 }
                    )
    
    # Adds annotations one by one with a loop
    for line in range(0, df.shape[0]):
         p1.text(df["x"][line],
                 df['y'][line],
                 '  ' + df["words"][line].title(),
                 horizontalalignment='left',
                 verticalalignment='bottom', size='medium',
                 color=df['color'][line],
                 weight='normal'
                ).set_size(15)

    
    plt.xlim(Y[:, 0].min()-50, Y[:, 0].max()+50)
    plt.ylim(Y[:, 1].min()-50, Y[:, 1].max()+50)
            
    plt.title('t-SNE visualization for {}'.format(word.title()))

# %%
tsnescatterplot(w2v_model, 'biden', [i[0] for i in w2v_model.wv.most_similar(negative=["biden"])])

# %%
w2v_model.wv.most_similar(positive=["biden"])
# Out:
# [('son', 0.9734784960746765),
#  ('joe_biden', 0.9700943231582642),
#  ('company', 0.9657618403434753),
#  ('board', 0.9641777276992798),
#  ('hunter', 0.962968647480011),
#  ('worked', 0.9602497816085815),
#  ('vice_president', 0.9601132273674011),
#  ('claims', 0.9596114158630371),
#  ('campaign', 0.95936119556427),
#  ('corruption', 0.9580628871917725)]

# %% [markdown]
# ## Sentiment Analysis

# %%
word_vectors = w2v_model.wv
model = KMeans(n_clusters=2, max_iter=1000, random_state=True, n_init=50).fit(X=word_vectors.vectors)
positive_cluster_center = model.cluster_centers_[0]
negative_cluster_center = model.cluster_centers_[1]

# %%
#model.cluster_centers_

# %%
word_vectors.similar_by_vector(model.cluster_centers_[0], topn=10, restrict_vocab=None)
# Out:
# [('rubin', 0.9999436736106873),
#  ('contrived', 0.9999411106109619),
#  ('imprisonment', 0.9999401569366455),
#  ('censorship', 0.999940037727356),
#  ('duplicate', 0.9999382495880127),
#  ('tha', 0.9999382495880127),
#  ('teddy', 0.9999380707740784),
#  ('flush', 0.999937891960144),
#  ('protester', 0.9999376535415649),
#  ('dressed', 0.999936044216156)]

# %%
words = pd.DataFrame(word_vectors.vocab.keys())
words.columns = ['words']
words['vectors'] = words.words.apply(lambda x: word_vectors.wv[f'{x}'])
words['cluster'] = words.vectors.apply(lambda x: model.predict([np.array(x)]))
words.cluster = words.cluster.apply(lambda x: x[0])
words['cluster_value'] = [1 if i==0 else -1 for i in words.cluster]
words['closeness_score'] = words.apply(lambda x: 1/(model.transform([x.vectors]).min()), axis=1)
words['sentiment_coeff'] = words.closeness_score * words.cluster_value
# Out:
# /Users/siddhipatel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
words
# Out:
#                       words  \
# 0                 president
# 1                     trump
# 2                     thank
# 3                      hang
# 4                        em
# ...                     ...
# 14195      wisconsinprimary
# 14196         trumpisaloser
# 14197                   caa
# 14198  americaworkstogether
# 14199                    gp
#
#                                                  vectors  cluster  \
# 0      [0.09005512, 0.058325462, 0.019639576, -0.0412...        0
# 1      [0.07960435, 0.061248135, 0.009246659, -0.0521...        0
# 2      [0.07881143, 0.039000057, 0.011824912, -0.0154...        0
# 3      [0.08196911, 0.04198753, 0.0063870465, -0.0214...        0
# 4      [0.08443287, 0.032673717, 0.00027479776, -0.02...        0
# ...                                                  ...      ...
# 14195  [0.08202684, 0.03854101, 0.0042507066, -0.0208...        0
# 14196  [0.08076347, 0.037439734, 0.0059369355, -0.019...        0
# 14197  [0.08543836, 0.03832225, 0.0053931125, -0.0192...        0
# 14198  [0.08238889, 0.03775217, 0.0037380834, -0.0209...        0
# 14199  [0.080487505, 0.03864209, 0.006368822, -0.0225...        0
#
#        cluster_value  closeness_score  sentiment_coeff
# 0                  1         4.539642         4.539642
# 1                  1         4.040623         4.040623
# 2                  1        12.184477        12.184477
# 3                  1        25.514709        25.514709
# 4                  1        13.461939        13.461939
# ...              ...              ...              ...
# 14195              1        56.541540        56.541540
# 14196              1        34.164310        34.164310
# 14197              1        27.470180        27.470180
# 14198              1        58.145002        58.145002
# 14199              1        51.814042        51.814042
#
# [14200 rows x 6 columns]

# %%
biden_df['Cleaned_Text'] = biden_df['Cleaned_Text'] .apply(lambda x: ' '.join(word for word in x))
biden_df
# Out:
#                             timestamp  Retweets  \
# 0      Thu Apr 25 16:59:59 +0000 2019         0
# 2      Thu Apr 25 16:59:58 +0000 2019         0
# 3      Thu Apr 25 16:59:57 +0000 2019         0
# 4      Thu Apr 25 16:59:57 +0000 2019         0
# 5      Thu Apr 25 16:59:57 +0000 2019         0
# ...                               ...       ...
# 52774  Sat Apr 11 11:49:39 +0000 2020         0
# 52776  Sat Apr 11 11:49:37 +0000 2020         0
# 52777  Sat Apr 11 11:49:36 +0000 2020         0
# 52779  Sat Apr 11 11:49:36 +0000 2020         0
# 52780  Sat Apr 11 11:49:35 +0000 2020         0
#
#                                                     Text Mentions  \
# 0                 And, we have President Trump to thank.      NaN
# 2      The “hang em high” references were less than s...      NaN
# 3      Donald Trump Makes Joe Biden’s Point, Mocking ...      NaN
# 4      Factually speaking, that’s not accurate. Trump...      NaN
# 5                                             HAAAAAA!!!      NaN
# ...                                                  ...      ...
# 52774                              #NeverBidenNeverTrump      NaN
# 52776  Yes he have to for some whom haven’t hear it b...      NaN
# 52777  No, no... this way Joe, this way........... th...      NaN
# 52779  LA voter- it literally doesn’t matter. You can...      NaN
# 52780  I think someone from Texas or Florida will be ...      NaN
#
#                     Hashtags  Sentiment  \
# 0                        NaN        0.0
# 2                        NaN        0.0
# 3                        NaN       -1.0
# 4                        NaN       -1.0
# 5                        NaN        0.0
# ...                      ...        ...
# 52774  #NeverBidenNeverTrump        NaN
# 52776                    NaN        NaN
# 52777                    NaN        NaN
# 52779                    NaN        NaN
# 52780                    NaN        NaN
#
#                                             Cleaned_Text
# 0                                  president trump thank
# 2                    hang em high references less subtle
# 3      donald trump makes joe biden point mocking can...
# 4      factually speaking accurate trump accused near...
# 5                                                haaaaaa
# ...                                                  ...
# 52774                               neverbidennevertrump
# 52776  yes hear wise reasonable know news outlets rep...
# 52777                                way joe way kitchen
# 52779  la voter literally matter stay home rest state...
# 52780              think someone texas florida picked vp
#
# [47100 rows x 7 columns]

# %%
biden_df = biden_df[biden_df['Sentiment'] != np.nan]
biden_df = biden_df[biden_df['Sentiment'] == -1]

# %%
row_and_indexes = pd.DataFrame(data = biden_df[['Cleaned_Text', 'Sentiment']].reset_index(drop=True))
row_and_indexes
# Out:
#                                           Cleaned_Text  Sentiment
# 0    donald trump makes joe biden point mocking can...       -1.0
# 1    factually speaking accurate trump accused near...       -1.0
# 2    asking joe biden intelligence president sits w...       -1.0
# 3                                         time run joe       -1.0
# 4                                                cares       -1.0
# ..                                                 ...        ...
# 650  brings child biden event encourages get ask qu...       -1.0
# 651  trump brazenly lies sticking joe biden unhinge...       -1.0
# 652  joebiden respond idiot everyone knows disgrace...       -1.0
# 653       joe specialty plagiarize everything get hans       -1.0
# 654                    liw life skies us embarrassment       -1.0
#
# [655 rows x 2 columns]

# %%
tfidf = TfidfVectorizer(tokenizer=lambda y: y.split(), norm=None)
tfidf.fit(biden_df['Cleaned_Text'])
features = pd.Series(tfidf.get_feature_names())
transformed = tfidf.transform(biden_df['Cleaned_Text'])
features
# Out:
# /Users/siddhipatel/opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:507: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn("The parameter 'token_pattern' will not be used"
# 0                //aflcio
# 1                //amazon
# 2                 //apple
# 3                   //bit
# 4       //canadafreepress
#               ...
# 3331                zarif
# 3332                 zero
# 3333                zilch
# 3334              zionist
# 3335          zurhd5bu1o8
# Length: 3336, dtype: object

# %%
def create_tfidf_dictionary(x, transformed_file, features):
    '''
    create dictionary for each input sentence x, where each word has assigned its tfidf score
    
    inspired  by function from this wonderful article: 
    https://medium.com/analytics-vidhya/automated-keyword-extraction-from-articles-using-nlp-bfd864f41b34
    
    x - row of dataframe, containing sentences, and their indexes,
    transformed_file - all sentences transformed with TfidfVectorizer
    features - names of all words in corpus used in TfidfVectorizer
    '''
    vector_coo = transformed_file[x.name].tocoo()
    vector_coo.col = features.iloc[vector_coo.col].values
    dict_from_coo = dict(zip(vector_coo.col, vector_coo.data))
    return dict_from_coo

def replace_tfidf_words(x, transformed_file, features):
    '''
    replacing each word with it's calculated tfidf dictionary with scores of each word
    x - row of dataframe, containing sentences, and their indexes,
    transformed_file - all sentences transformed with TfidfVectorizer
    features - names of all words in corpus used in TfidfVectorizer
    '''
    dictionary = create_tfidf_dictionary(x, transformed_file, features)   
    return list(map(lambda y:dictionary[f'{y}'], x.Cleaned_Text.split()))
    
replaced_tfidf_scores = row_and_indexes.apply(lambda x: replace_tfidf_words(x, transformed, features), axis=1)

# %%
replaced_tfidf_scores
# Out:
# 0      [4.652947444887873, 5.380740486694696, 11.0805...
# 1      [6.793013608384144, 6.099866427824199, 6.38754...
# 2      [5.876722876509988, 1.6426163719127294, 1.7431...
# 3      [4.541721809777648, 5.088265516145719, 1.64261...
# 4                                    [5.876722876509988]
#                              ...
# 650    [13.586027216768288, 5.2889362116078695, 5.229...
# 651    [2.690370243347348, 13.586027216768288, 10.813...
# 652    [2.6739764335716716, 6.3875485002759795, 5.288...
# 653    [1.6426163719127294, 6.793013608384144, 6.7930...
# 654    [6.793013608384144, 5.540250639888776, 6.79301...
# Length: 655, dtype: object

# %%
sentiment_map = words
sentiment_dict = dict(zip(sentiment_map.words.values, sentiment_map.sentiment_coeff.values))

# %%
def replace_sentiment_words(word, sentiment_dict):
    '''
    replacing each word with its associated sentiment score from sentiment dict
    '''
    try:
        out = sentiment_dict[word]
    except KeyError:
        out = 0
    return out

replaced_closeness_scores = row_and_indexes['Cleaned_Text'].apply(lambda x: list(map(lambda y: replace_sentiment_words(y, sentiment_dict), x.split())))
replaced_closeness_scores
# Out:
# 0      [8.233043627855018, 4.040623316285427, 10.2262...
# 1      [49.788483017213, 17.43111408195668, 33.119377...
# 2      [15.266329608207329, 3.733417775765308, 2.3957...
# 3      [7.089307034328262, 10.378012291354713, 3.7334...
# 4                                   [16.612738124542933]
#                              ...
# 650    [15.17437103017262, 11.968887133700807, 2.3957...
# 651    [4.040623316285427, 0, 13.395935541856458, 21....
# 652    [-3.5097897736203434, 29.541219571205847, 17.7...
# 653    [3.733417775765308, 36.2548458414366, 54.19152...
# 654    [0, 7.187027571263889, 0, 5.511086485339778, 3...
# Name: Cleaned_Text, Length: 655, dtype: object

# %%
replacement_df = pd.DataFrame(data=[replaced_closeness_scores, replaced_tfidf_scores, row_and_indexes['Cleaned_Text'], row_and_indexes['Sentiment']]).T
replacement_df.columns = ['sentiment_coeff', 'tfidf_scores', 'sentence', 'sentiment']
replacement_df['sentiment_rate'] = replacement_df.apply(lambda x: np.array(x.loc['sentiment_coeff']) @ np.array(x.loc['tfidf_scores']), axis=1)
replacement_df['prediction'] = (replacement_df.sentiment_rate>0).astype('int8')
replacement_df['sentiment'] = [1 if i==1 else 0 for i in replacement_df.sentiment]
replacement_df
# Out:
#                                        sentiment_coeff  \
# 0    [8.233043627855018, 4.040623316285427, 10.2262...
# 1    [49.788483017213, 17.43111408195668, 33.119377...
# 2    [15.266329608207329, 3.733417775765308, 2.3957...
# 3    [7.089307034328262, 10.378012291354713, 3.7334...
# 4                                 [16.612738124542933]
# ..                                                 ...
# 650  [15.17437103017262, 11.968887133700807, 2.3957...
# 651  [4.040623316285427, 0, 13.395935541856458, 21....
# 652  [-3.5097897736203434, 29.541219571205847, 17.7...
# 653  [3.733417775765308, 36.2548458414366, 54.19152...
# 654  [0, 7.187027571263889, 0, 5.511086485339778, 3...
#
#                                           tfidf_scores  \
# 0    [4.652947444887873, 5.380740486694696, 11.0805...
# 1    [6.793013608384144, 6.099866427824199, 6.38754...
# 2    [5.876722876509988, 1.6426163719127294, 1.7431...
# 3    [4.541721809777648, 5.088265516145719, 1.64261...
# 4                                  [5.876722876509988]
# ..                                                 ...
# 650  [13.586027216768288, 5.2889362116078695, 5.229...
# 651  [2.690370243347348, 13.586027216768288, 10.813...
# 652  [2.6739764335716716, 6.3875485002759795, 5.288...
# 653  [1.6426163719127294, 6.793013608384144, 6.7930...
# 654  [6.793013608384144, 5.540250639888776, 6.79301...
#
#                                               sentence  sentiment  \
# 0    donald trump makes joe biden point mocking can...          0
# 1    factually speaking accurate trump accused near...          0
# 2    asking joe biden intelligence president sits w...          0
# 3                                         time run joe          0
# 4                                                cares          0
# ..                                                 ...        ...
# 650  brings child biden event encourages get ask qu...          0
# 651  trump brazenly lies sticking joe biden unhinge...          0
# 652  joebiden respond idiot everyone knows disgrace...          0
# 653       joe specialty plagiarize everything get hans          0
# 654                    liw life skies us embarrassment          0
#
#      sentiment_rate  prediction
# 0        722.612889           1
# 1       3986.813332           1
# 2       1373.599758           1
# 3         91.136316           1
# 4         97.628458           1
# ..              ...         ...
# 650     1529.326329           1
# 651     2385.718160           1
# 652     2898.169663           1
# 653      680.538856           1
# 654      279.542901           1
#
# [655 rows x 6 columns]

# %%
predicted_classes = replacement_df.prediction
y_test = replacement_df.sentiment

conf_matrix = pd.DataFrame(confusion_matrix(replacement_df.sentiment, replacement_df.prediction))
print('Confusion Matrix')
display(conf_matrix)

test_scores = accuracy_score(y_test,predicted_classes), precision_score(y_test, predicted_classes), recall_score(y_test, predicted_classes), f1_score(y_test, predicted_classes)

print('\n \n Scores')
scores = pd.DataFrame(data=[test_scores])
scores.columns = ['accuracy', 'precision', 'recall', 'f1']
scores = scores.T
scores.columns = ['scores']
display(scores)
# Out:
# Confusion Matrix
#    0    1
# 0  2  653
# 1  0    0
#
#  Scores
# /Users/siddhipatel/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#              scores
# accuracy   0.003053
# precision  0.000000
# recall     0.000000
# f1         0.000000
