# %%
import pandas as pd
import numpy as np
import re

#for sentiment analyzing
import nltk
import random
from nltk.tokenize import word_tokenize

#for basic preprocessing
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
from nltk.text import Text
import string, re
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/siddhipatel/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/siddhipatel/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/siddhipatel/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
#HELPER FUNCTIONS

#remove punctuations, numbers, and special characters
def remove_special(df):
    df['Text'] = df['Text'].str.replace("[^\w\d'\s]+", '')
    return df

# %%
def clean_up(text):

# %%
biden_url = 'https://raw.githubusercontent.com/srpatel2000/Elections2020/master/Tweets/2020_Elections/Biden_Tweets.csv'
biden_df = pd.read_csv(biden_url, error_bad_lines= False)
biden_df
# Out:
#                             timestamp             Username  Retweets  \
# 0      Thu Apr 25 16:59:59 +0000 2019   980275870655893504         0
# 1      Thu Apr 25 16:59:59 +0000 2019            102468365         0
# 2      Thu Apr 25 16:59:58 +0000 2019   827325184432603136         0
# 3      Thu Apr 25 16:59:57 +0000 2019   753734119893393408         0
# 4      Thu Apr 25 16:59:57 +0000 2019            140074335         0
# ...                               ...                  ...       ...
# 52795  Sat Apr 11 11:49:37 +0000 2020  1236376132825612290         0
# 52796  Sat Apr 11 11:49:36 +0000 2020   874403447667404800         0
# 52797  Sat Apr 11 11:49:36 +0000 2020  1010964754708303872         0
# 52798  Sat Apr 11 11:49:36 +0000 2020           3775550189         0
# 52799  Sat Apr 11 11:49:35 +0000 2020  1225504409809047552         0
#
#                                                     Text Mentions  \
# 0                 And, we have President Trump to thank.      NaN
# 1                             pic.twitter.com/PxypFuZzdb      NaN
# 2      The “hang em high” references were less than s...      NaN
# 3      Donald Trump Makes Joe Biden’s Point, Mocking ...      NaN
# 4      Factually speaking, that’s not accurate. Trump...      NaN
# ...                                                  ...      ...
# 52795  Yes he have to for some whom haven’t hear it b...      NaN
# 52796  No, no... this way Joe, this way........... th...      NaN
# 52797  You want more of this? #TaraReadeBlackoutpic.t...      NaN
# 52798  LA voter- it literally doesn’t matter. You can...      NaN
# 52799  I think someone from Texas or Florida will be ...      NaN
#
#                     Hashtags
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 52795                    NaN
# 52796                    NaN
# 52797  #TaraReadeBlackoutpic
# 52798                    NaN
# 52799                    NaN
#
# [52800 rows x 6 columns]

# %%
biden_df_test = remove_special(biden_df)
biden_df_test
# Out:
#                             timestamp             Username  Retweets  \
# 0      Thu Apr 25 16:59:59 +0000 2019   980275870655893504         0
# 1      Thu Apr 25 16:59:59 +0000 2019            102468365         0
# 2      Thu Apr 25 16:59:58 +0000 2019   827325184432603136         0
# 3      Thu Apr 25 16:59:57 +0000 2019   753734119893393408         0
# 4      Thu Apr 25 16:59:57 +0000 2019            140074335         0
# ...                               ...                  ...       ...
# 52795  Sat Apr 11 11:49:37 +0000 2020  1236376132825612290         0
# 52796  Sat Apr 11 11:49:36 +0000 2020   874403447667404800         0
# 52797  Sat Apr 11 11:49:36 +0000 2020  1010964754708303872         0
# 52798  Sat Apr 11 11:49:36 +0000 2020           3775550189         0
# 52799  Sat Apr 11 11:49:35 +0000 2020  1225504409809047552         0
#
#                                                     Text Mentions  \
# 0                   And we have President Trump to thank      NaN
# 1                                pictwittercomPxypFuZzdb      NaN
# 2      The hang em high references were less than subtle      NaN
# 3      Donald Trump Makes Joe Bidens Point Mocking Ca...      NaN
# 4      Factually speaking thats not accurate Trump ha...      NaN
# ...                                                  ...      ...
# 52795  Yes he have to for some whom havent hear it be...      NaN
# 52796     No no this way Joe this way that's the kitchen      NaN
# 52797  You want more of this TaraReadeBlackoutpictwit...      NaN
# 52798  LA voter it literally doesnt matter You can st...      NaN
# 52799  I think someone from Texas or Florida will be ...      NaN
#
#                     Hashtags
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 52795                    NaN
# 52796                    NaN
# 52797  #TaraReadeBlackoutpic
# 52798                    NaN
# 52799                    NaN
#
# [52800 rows x 6 columns]

# %%
string = "warhol's art used many types of media, including hand drawing, painting, photography, silk screening, sculpture, film, music."
print (re.sub("[^\w\d'\s]+",'',string))
# Out:
# warhol's art used many types of media including hand drawing painting photography silk screening sculpture film music
